# %%
# !git clone https://github.com/Laghoub/studentFrocasting.git
# Out:
# Cloning into 'studentFrocasting'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 45 (delta 8), reused 38 (delta 5), pack-reused 0
# Unpacking objects: 100% (45/45), done.

# %% [markdown]
# ## Installation des bibliotheques necessaires

# %% [markdown]
# ## Dans un prmier temps nous installons les modules necessaires

# %% [markdown]
# **NumPy** (pour Numerical Python) est un outil parfait pour le calcul scientifique et la réalisation d’opérations de base et avancées avec des tableaux.
#
# **Pandas** est une bibliothèque créée pour aider les développeurs à travailler intuitivement avec des données « étiquetées » et « relationnelles ». Elle est basée sur deux structures de données principales : « Série » (unidimensionnelle, comme une liste Python) et « Dataframe » (bidimensionnelle, comme un tableau à plusieurs colonnes).
#
# **Matplotlib** est une bibliothèque scientifique de données standard qui aide à générer des visualisations de données telles que des diagrammes et des graphiques bidimensionnels (histogrammes, diagrammes de dispersion, graphiques de coordonnées non cartésiennes).
#
# **Seaborn** est basé sur Matplotlib et sert d’outil de Machine Learning Python utile pour la visualisation de modèles statistiques – cartes thermiques et autres types de visualisations qui résument les données et dépeignent les distributions globales.
#
# **TensorFlow** est un framework Python populaire pour le Machine Learning et le Deep Learning, qui a été développé à Google Brain. C’est le meilleur outil pour des tâches comme l’identification d’objets, la reconnaissance vocale et bien d’autres. Il permet de travailler avec des réseaux neuronaux artificiels qui doivent gérer plusieurs ensembles de données.

# %%
from random import choices
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix 
import lightgbm as lgb

# %% [markdown]
# ## **Génération de la table météo**

# %%
Type = ['Ensoleillé' , 'Nuageux' , 'Pluvieux']
weightsSep = [0.75,0.25,0]
weightsOct = [0.25,0.75,0]
weightsNov = [0.2,0.8,0.2]
weightshiv = [0,0.3,0.7]
weightsmars = [0.1,0.2,0.7]
weightsAvr = [0.25,0.4,0.35]
weightsmai = [0.5,0.4,0.1]
weightsete = [0.95,0.05,0]

# %%
ListDate = []

# %%
import datetime
for i in range(1080):
    date = datetime.datetime(2019,9,1,12,4,5) + datetime.timedelta(days=i)
    dateStr = date.strftime("%d-%m-%Y")
    ListDate.append(dateStr)    

ListDate

# %%
for j in range(30):
    choix = choices(Type,weightsSep)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsOct)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsNov)[0]
    meteo.append(choix)

# %%
for j in range(90):
    choix = choices(Type,weightshiv)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsmars)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsAvr)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsmai)[0]
    meteo.append(choix)

# %%
for j in range(90):
    choix = choices(Type,weightsete)[0]
    meteo.append(choix)

# %%
len(meteo)

# %%
len(ListDate)

# %%
datameteo = {
  "date": ListDate,
  "meteo": meteo
}
df_meteo = pd.DataFrame(datameteo)

# %%
df

# %%
df.to_excel("datameteo.xlsx")

# %%
dataevent = pd.read_excel("/content/studentFrocasting/event.xlsx")
dataevent
# Out:
#       Unnamed: 0        date    Event
# 0              0  01-09-2019   Normal
# 1              1  02-09-2019   Normal
# 2              2  03-09-2019   Normal
# 3              3  04-09-2019   Normal
# 4              4  05-09-2019   Normal
# ...          ...         ...      ...
# 1075        1075  11-08-2022   Normal
# 1076        1076  12-08-2022  Weekend
# 1077        1077  13-08-2022   Normal
# 1078        1078  14-08-2022   Normal
# 1079        1079  15-08-2022   Normal
#
# [1080 rows x 3 columns]

# %%
donnees = pd.read_excel("/content/studentFrocasting/menu.xlsx")
donnees
# Out:
#      idRestaurant        date  Type       Plat
# 0          Esi016  01-09-2019  midi  Lentilles
# 1          Esi016  02-09-2019  midi     Loubia
# 2          Esi016  03-09-2019  midi        Riz
# 3          Esi016  04-09-2019  midi  Spaghetti
# 4          Esi016  05-09-2019  midi   Couscous
# ...           ...         ...   ...        ...
# 3235  Bouraoui016  11-08-2022  soir   Couscous
# 3236  Bouraoui016  12-08-2022  soir  Lentilles
# 3237  Bouraoui016  13-08-2022  soir      Kebab
# 3238  Bouraoui016  14-08-2022  soir     Frites
# 3239  Bouraoui016  15-08-2022  soir  Spaghetti
#
# [3240 rows x 4 columns]

# %%
salaire = [random.randrange(18000,25000), random.randrange(25000,40000) , random.randrange(40000,50000), random.randrange(50000,60000),
           random.randrange(60000,80000),random.randrange(80000,100000), random.randrange(100000,120000), 
          random.randrange(120000,150000), random.randrange(150000,200000)]
poids = [0.20,0.15,0.2,0.15,0.1,0.06,0.06,0.05,0.03]
moyDesRev = []

# %% [markdown]
# # génération de la colonne moyenne des revenus

# %%
for i in range (nbEtud):
    moyDesRev.append(choices(salaire,poids)[0])

# %%
moyDesRev

# %% [markdown]
# # La colonne hebergement

# %%
hebergTypes = ['interne' , 'externe']
poidsHeb = [0.3 , 0.7]
listHeb = []
nbEtud = 1000

# %%
for i in range(nbEtud):
    listHeb.append(choices(hebergTypes,poidsHeb)[0])

# %%
len(listHeb)
# Out:
# 1000

# %%
population = {
  "Heberg": listHeb,
  "Rev_par": moyDesRev
}
pop = pd.DataFrame(population)

# %%
pop
# Out:
#       Heberg  Rev_par
# 0    interne    75146
# 1    externe    28302
# 2    externe    28302
# 3    interne    47814
# 4    externe    28302
# ..       ...      ...
# 995  externe   106774
# 996  externe   143862
# 997  interne    19304
# 998  externe    52289
# 999  externe    52289
#
# [1000 rows x 2 columns]

# %%
pop.to_excel("/content/studentFrocasting/newdata/etudiants.xlsx")

# %% [markdown]
# # La table population

# %%
df_population = pd.read_excel("/content/studentFrocasting/newdata/etudiants.xlsx")
df_population
# Out:
#      Unnamed: 0   Heberg  Rev_par
# 0             0  interne    75146
# 1             1  externe    28302
# 2             2  externe    28302
# 3             3  interne    47814
# 4             4  externe    28302
# ..          ...      ...      ...
# 995         995  externe   106774
# 996         996  externe   143862
# 997         997  interne    19304
# 998         998  externe    52289
# 999         999  externe    52289
#
# [1000 rows x 3 columns]

# %%
df_event= pd.read_excel("/content/studentFrocasting/event.xlsx")
df_event
# Out:
#       Unnamed: 0        date    Event
# 0              0  01-09-2019   Normal
# 1              1  02-09-2019   Normal
# 2              2  03-09-2019   Normal
# 3              3  04-09-2019   Normal
# 4              4  05-09-2019   Normal
# ...          ...         ...      ...
# 1075        1075  11-08-2022   Normal
# 1076        1076  12-08-2022  Weekend
# 1077        1077  13-08-2022   Normal
# 1078        1078  14-08-2022   Normal
# 1079        1079  15-08-2022   Normal
#
# [1080 rows x 3 columns]

# %%
df_meteo = pd.read_excel("/content/studentFrocasting/meteo.xlsx")
df_meteo
# Out:
#       Unnamed: 0        date       meteo
# 0              0  01-09-2019  Ensoleillé
# 1              1  02-09-2019  Ensoleillé
# 2              2  03-09-2019  Ensoleillé
# 3              3  04-09-2019  Ensoleillé
# 4              4  05-09-2019  Ensoleillé
# ...          ...         ...         ...
# 1075        1075  11-08-2022  Ensoleillé
# 1076        1076  12-08-2022  Ensoleillé
# 1077        1077  13-08-2022  Ensoleillé
# 1078        1078  14-08-2022  Ensoleillé
# 1079        1079  15-08-2022  Ensoleillé
#
# [1080 rows x 3 columns]

# %%
df_menu=pd.read_excel("/content/studentFrocasting/menu.xlsx")

# %%
df_menu_Esi=df_menu.loc[df_menu['idRestaurant'] == "Esi016"]
df_menu_Esi
# Out:
#      idRestaurant        date  Type       Plat
# 0          Esi016  01-09-2019  midi  Lentilles
# 1          Esi016  02-09-2019  midi     Loubia
# 2          Esi016  03-09-2019  midi        Riz
# 3          Esi016  04-09-2019  midi  Spaghetti
# 4          Esi016  05-09-2019  midi   Couscous
# ...           ...         ...   ...        ...
# 1075       Esi016  11-08-2022  midi   Couscous
# 1076       Esi016  12-08-2022  midi    Weekend
# 1077       Esi016  13-08-2022  midi    Weekend
# 1078       Esi016  14-08-2022  midi  Lentilles
# 1079       Esi016  15-08-2022  midi     Loubia
#
# [1080 rows x 4 columns]

# %%
result = pd.merge(df_menu_Esi,df_meteo, on="date")
result2 = pd.merge(result,df_event, on="date")

# %%
result2
# Out:
#      idRestaurant        date  Type       Plat  Unnamed: 0_x       meteo  \
# 0          Esi016  01-09-2019  midi  Lentilles             0  Ensoleillé
# 1          Esi016  02-09-2019  midi     Loubia             1  Ensoleillé
# 2          Esi016  03-09-2019  midi        Riz             2  Ensoleillé
# 3          Esi016  04-09-2019  midi  Spaghetti             3  Ensoleillé
# 4          Esi016  05-09-2019  midi   Couscous             4  Ensoleillé
# ...           ...         ...   ...        ...           ...         ...
# 1075       Esi016  11-08-2022  midi   Couscous          1075  Ensoleillé
# 1076       Esi016  12-08-2022  midi    Weekend          1076  Ensoleillé
# 1077       Esi016  13-08-2022  midi    Weekend          1077  Ensoleillé
# 1078       Esi016  14-08-2022  midi  Lentilles          1078  Ensoleillé
# 1079       Esi016  15-08-2022  midi     Loubia          1079  Ensoleillé
#
#       Unnamed: 0_y    Event
# 0                0   Normal
# 1                1   Normal
# 2                2   Normal
# 3                3   Normal
# 4                4   Normal
# ...            ...      ...
# 1075          1075   Normal
# 1076          1076  Weekend
# 1077          1077   Normal
# 1078          1078   Normal
# 1079          1079   Normal
#
# [1080 rows x 8 columns]

# %%
resultf = result2.drop(columns=["Unnamed: 0_x","Unnamed: 0_y"], axis=1)

# %%
resultf
# Out:
#      idRestaurant        date  Type       Plat       meteo    Event
# 0          Esi016  01-09-2019  midi  Lentilles  Ensoleillé   Normal
# 1          Esi016  02-09-2019  midi     Loubia  Ensoleillé   Normal
# 2          Esi016  03-09-2019  midi        Riz  Ensoleillé   Normal
# 3          Esi016  04-09-2019  midi  Spaghetti  Ensoleillé   Normal
# 4          Esi016  05-09-2019  midi   Couscous  Ensoleillé   Normal
# ...           ...         ...   ...        ...         ...      ...
# 1075       Esi016  11-08-2022  midi   Couscous  Ensoleillé   Normal
# 1076       Esi016  12-08-2022  midi    Weekend  Ensoleillé  Weekend
# 1077       Esi016  13-08-2022  midi    Weekend  Ensoleillé   Normal
# 1078       Esi016  14-08-2022  midi  Lentilles  Ensoleillé   Normal
# 1079       Esi016  15-08-2022  midi     Loubia  Ensoleillé   Normal
#
# [1080 rows x 6 columns]

# %%
df_pop = pd.read_excel("/content/studentFrocasting/newdata/etudiants.xlsx")
df_pop
# Out:
#     idEtudiant   Heberg  Rev_par bourse  idRestaurant
# 0      17/0001  interne    75146     Oui       Esi016
# 1      17/0002  externe    28302     Oui       Esi016
# 2      17/0003  externe    28302     Oui       Esi016
# 3      17/0004  interne    47814     Oui       Esi016
# 4      17/0005  externe    28302     Oui       Esi016
# ..         ...      ...      ...     ...          ...
# 995    17/0996  externe   106774     Oui       Esi016
# 996    17/0997  externe   143862     Non       Esi016
# 997    17/0998  interne    19304     Oui       Esi016
# 998    17/0999  externe    52289     Oui       Esi016
# 999    17/1000  externe    52289     Oui       Esi016
#
# [1000 rows x 5 columns]

# %%
resultMerge = pd.merge(resultf,df_pop, on="idRestaurant")
resultMerge
# Out:
#         idRestaurant        date  Type       Plat       meteo   Event  \
# 0             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...              ...         ...   ...        ...         ...     ...
# 1079995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#         idEtudiant   Heberg  Rev_par bourse
# 0          17/0001  interne    75146     Oui
# 1          17/0002  externe    28302     Oui
# 2          17/0003  externe    28302     Oui
# 3          17/0004  interne    47814     Oui
# 4          17/0005  externe    28302     Oui
# ...            ...      ...      ...     ...
# 1079995    17/0996  externe   106774     Oui
# 1079996    17/0997  externe   143862     Non
# 1079997    17/0998  interne    19304     Oui
# 1079998    17/0999  externe    52289     Oui
# 1079999    17/1000  externe    52289     Oui
#
# [1080000 rows x 10 columns]

# %%
resultMerge.to_csv("/content/studentFrocasting/newdata/dataset.csv")

# %%
table = pd.read_csv("/content/studentFrocasting/newdata/dataset.csv")
table
# Out:
#          Unnamed: 0 idRestaurant        date  Type       Plat       meteo  \
# 0                 0       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 1                 1       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 2                 2       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 3                 3       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 4                 4       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# ...             ...          ...         ...   ...        ...         ...
# 1079995     1079995       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 1079996     1079996       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 1079997     1079997       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 1079998     1079998       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 1079999     1079999       Esi016  15-08-2022  midi     Loubia  Ensoleillé
#
#           Event idEtudiant   Heberg  Rev_par bourse
# 0        Normal    17/0001  interne    75146     Oui
# 1        Normal    17/0002  externe    28302     Oui
# 2        Normal    17/0003  externe    28302     Oui
# 3        Normal    17/0004  interne    47814     Oui
# 4        Normal    17/0005  externe    28302     Oui
# ...         ...        ...      ...      ...     ...
# 1079995  Normal    17/0996  externe   106774     Oui
# 1079996  Normal    17/0997  externe   143862     Non
# 1079997  Normal    17/0998  interne    19304     Oui
# 1079998  Normal    17/0999  externe    52289     Oui
# 1079999  Normal    17/1000  externe    52289     Oui
#
# [1080000 rows x 11 columns]

# %%
table2 = table.drop(columns=['Unnamed: 0'], axis=1)
table2
# Out:
#         idRestaurant        date  Type       Plat       meteo   Event  \
# 0             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...              ...         ...   ...        ...         ...     ...
# 1079995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#         idEtudiant   Heberg  Rev_par bourse
# 0          17/0001  interne    75146     Oui
# 1          17/0002  externe    28302     Oui
# 2          17/0003  externe    28302     Oui
# 3          17/0004  interne    47814     Oui
# 4          17/0005  externe    28302     Oui
# ...            ...      ...      ...     ...
# 1079995    17/0996  externe   106774     Oui
# 1079996    17/0997  externe   143862     Non
# 1079997    17/0998  interne    19304     Oui
# 1079998    17/0999  externe    52289     Oui
# 1079999    17/1000  externe    52289     Oui
#
# [1080000 rows x 10 columns]

# %%
# Out:
# 0          Lentilles
# 1          Lentilles
# 2          Lentilles
# 3          Lentilles
# 4          Lentilles
#              ...
# 1079995       Loubia
# 1079996       Loubia
# 1079997       Loubia
# 1079998       Loubia
# 1079999       Loubia
# Name: Plat, Length: 1080000, dtype: object

# %% [markdown]
# # Probabilité selon le plat

# %%
def probPlat(plat):
    if (plat=="Lentilles"):
        return 0.1
    if (plat=="Loubia"):
        return 0.12
    if (plat=="Riz"):
        return 0.4*0.2
    if (plat=="Spaghetti"):
        return 0.3*0.2
    if (plat=="Couscous"):
        return 0.9*0.2
    else: return 0

# %%
probPlat("Couscous")
# Out:
# 0.18000000000000002

# %% [markdown]
# # Probabilité selon la météo

# %%
def probMeteo(meteo):
    if (meteo=="Ensoleillé"):
        return 0.02
    if (meteo=="Nuageux"):
        return 0.06
    if (meteo=="Mauvais"):
        return 0.09

# %% [markdown]
# # Probabilité selon la bourse

# %%
def probBourse(bourse):
    if(bourse=="Oui"):
        return 0.7*0.1
    if(bourse=="Non"):
        return 0.6*0.1

# %%
probBourse('Oui')
# Out:
# 0.06999999999999999

# %% [markdown]
# # Probabilité selon l'hébergement

# %%
def probHeberg(heberg):
    if(heberg=="externe"):
        return 0.25*0.8
    if(heberg=="interne"):
        return 0.25*0.5

# %% [markdown]
# # probabilité selon les revenues des parents

# %%
def probRevenues(revenu):
    if(revenu<50000):
        return 0.9*0.35
    if(revenu>50000 and revenu<100000):
        return 0.6*0.35
    if (revenu>100000 and revenu<150000):
        return 0.3*0.35
    if (revenu>150000):
        return 0.05*0.35

# %% [markdown]
# # probabilité selon les evenements

# %%
def probEvent(event):
    if(event=="Normal"):
        return 1
    return 0

# %%
probEvent("Normal")
# Out:
# 1

# %%
table3 = table2.assign(presence=0.001)

# %%
table3.rename(columns = {'bourse ':'Bourse'}, inplace = True)

# %%
table3
# Out:
#         idRestaurant        date  Type       Plat       meteo   Event  \
# 0             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...              ...         ...   ...        ...         ...     ...
# 1079995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#         idEtudiant   Heberg  Rev_par Bourse  presence
# 0          17/0001  interne    75146    Oui     0.001
# 1          17/0002  externe    28302    Oui     0.001
# 2          17/0003  externe    28302    Oui     0.001
# 3          17/0004  interne    47814    Oui     0.001
# 4          17/0005  externe    28302    Oui     0.001
# ...            ...      ...      ...    ...       ...
# 1079995    17/0996  externe   106774    Oui     0.001
# 1079996    17/0997  externe   143862    Non     0.001
# 1079997    17/0998  interne    19304    Oui     0.001
# 1079998    17/0999  externe    52289    Oui     0.001
# 1079999    17/1000  externe    52289    Oui     0.001
#
# [1080000 rows x 11 columns]

# %%
for i in range(1080000):
    table3["presence"][i] =(probPlat(table3["Plat"][i])+probMeteo(table3["meteo"][i])+probBourse(table3["Bourse"][i])+probHeberg(table3["Heberg"][i])+probRevenues(table3["Rev_par"][i]))*probEvent(table3["Event"][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
table3
# Out:
#         idRestaurant        date  Type       Plat       meteo   Event  \
# 0             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4             Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...              ...         ...   ...        ...         ...     ...
# 1079995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 1079999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#         idEtudiant   Heberg  Rev_par Bourse  presence
# 0          17/0001  interne    75146    Oui     0.525
# 1          17/0002  externe    28302    Oui     0.705
# 2          17/0003  externe    28302    Oui     0.705
# 3          17/0004  interne    47814    Oui     0.630
# 4          17/0005  externe    28302    Oui     0.705
# ...            ...      ...      ...    ...       ...
# 1079995    17/0996  externe   106774    Oui     0.515
# 1079996    17/0997  externe   143862    Non     0.505
# 1079997    17/0998  interne    19304    Oui     0.650
# 1079998    17/0999  externe    52289    Oui     0.620
# 1079999    17/1000  externe    52289    Oui     0.620
#
# [1080000 rows x 11 columns]

# %%
table3.to_csv("/content/studentFrocasting/newdata/dataset0.csv")

# %%
table3 =pd.read_csv("/content/studentFrocasting/newdata/dataset0.csv")

# %%
table3.rename(columns={'presence': 'presenceP'}, inplace=True)

# %%
table3 = table3.assign(presence=0)
table3
# Out:
#          Unnamed: 0 idRestaurant        date  Type       Plat       meteo  \
# 0                 0       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 1                 1       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 2                 2       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 3                 3       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 4                 4       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# ...             ...          ...         ...   ...        ...         ...
# 1079995     1079995       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 1079996     1079996       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 1079997     1079997       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 1079998     1079998       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 1079999     1079999       Esi016  15-08-2022  midi     Loubia  Ensoleillé
#
#           Event idEtudiant   Heberg  Rev_par Bourse  presenceP  presence
# 0        Normal    17/0001  interne    75146    Oui      0.525         0
# 1        Normal    17/0002  externe    28302    Oui      0.705         0
# 2        Normal    17/0003  externe    28302    Oui      0.705         0
# 3        Normal    17/0004  interne    47814    Oui      0.630         0
# 4        Normal    17/0005  externe    28302    Oui      0.705         0
# ...         ...        ...      ...      ...    ...        ...       ...
# 1079995  Normal    17/0996  externe   106774    Oui      0.515         0
# 1079996  Normal    17/0997  externe   143862    Non      0.505         0
# 1079997  Normal    17/0998  interne    19304    Oui      0.650         0
# 1079998  Normal    17/0999  externe    52289    Oui      0.620         0
# 1079999  Normal    17/1000  externe    52289    Oui      0.620         0
#
# [1080000 rows x 13 columns]

# %%
def decide(presP):
    Type = [0,1]
    weight = [1-presP,presP]
    return choices(Type,weight)[0]

# %%
decide(0.2)
# Out:
# 1

# %%
for i in range(1080000):
    table3["presence"][i] = decide(table3["presenceP"][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
table3
# Out:
#         Unnamed: 0 idRestaurant        date  Type       Plat       meteo  \
# 0                0       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 1                1       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 2                2       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 3                3       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 4                4       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# ...            ...          ...         ...   ...        ...         ...
# 215995      215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215996      215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215997      215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215998      215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215999      215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé
#
#          Event idEtudiant   Heberg  Rev_par Bourse  presenceP  presence
# 0       Normal    17/0001  interne    56879    Oui      0.525         0
# 1       Normal    17/0002  externe    19184    Oui      0.705         1
# 2       Normal    17/0003  externe    56879    Oui      0.600         1
# 3       Normal    17/0004  externe    19184    Oui      0.705         1
# 4       Normal    17/0005  interne   139936    Non      0.410         0
# ...        ...        ...      ...      ...    ...        ...       ...
# 215995  Normal    17/0196  interne    25251    Oui      0.650         1
# 215996  Normal    17/0197  interne    19184    Oui      0.650         1
# 215997  Normal    17/0198  interne    56879    Oui      0.545         0
# 215998  Normal    17/0199  interne    56879    Oui      0.545         0
# 215999  Normal    17/0200  externe    46901    Oui      0.725         1
#
# [216000 rows x 13 columns]

# %%
table3.to_csv("/content/studentFrocasting/newdata/tablePredection.csv")

# %%
f,ax = plt.subplots(1,1,figsize=(20,8))
plt1 = table3.groupby(['date'], as_index=False).agg({'presence': np.sum})
plt1=plt1.set_index('date')
plt1.plot(color='salmon', kind='area', ax=ax)
plt.ylabel("Total des présents")
plt.title("Répartitions des présents par date")
# Out:
# Text(0.5, 1.0, 'Répartitions des présents par date')

# %%
table4=table3.groupby(['date'],as_index=False).sum()

# %%
table4 = table4[['date','presence']].sort_values(by=['date'], 
ascending=True)

# %%
table4
# Out:
#             date  presence
# 0     01-01-2020         0
# 1     01-01-2021         0
# 2     01-01-2022         0
# 3     01-02-2020       594
# 4     01-02-2021       738
# ...          ...       ...
# 1075  31-10-2020       548
# 1076  31-10-2021       649
# 1077  31-12-2019       629
# 1078  31-12-2020       760
# 1079  31-12-2021         0
#
# [1080 rows x 2 columns]

# %%
table4.to_excel('/content/studentFrocasting/newdata/tablePres.xlsx')

# %%
nbpres = pd.read_excel("/content/studentFrocasting/newdata/tablePres.xlsx")
nbpres
# Out:
#            date  presence
# 0    2019-09-01       617
# 1    2019-09-02       620
# 2    2019-09-03       585
# 3    2019-09-04       604
# 4    2019-09-05       702
# ...         ...       ...
# 1075 2022-08-11       694
# 1076 2022-08-12         0
# 1077 2022-08-13       503
# 1078 2022-08-14       633
# 1079 2022-08-15       656
#
# [1080 rows x 2 columns]

# %%
f,ax = plt.subplots(1,1,figsize=(20,8))
plt1=nbpres.set_index('date')
plt1.plot(color='salmon', kind='area', ax=ax)
plt.ylabel("Total des présents")
plt.title("Répartitions des présents par date")
# Out:
# Text(0.5, 1.0, 'Répartitions des présents par date')

# %%
plt.figure(figsize=(15,7))
plt.plot(nbpres['date'][0:365], nbpres['presence'][0:365])
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")
plt.show()

# %%
for i in range(1080):
    pres['date'][i] = str(pres['date'][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-115-ddd46002ab60> in <module>()
# ----> 1 presn = pd.read_excel("/content/studentFrocasting/newdata/datasetPFE.xlsx")
#       2 presn
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1190             else:
#    1191                 ext = inspect_excel_format(
# -> 1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#    1194                 if ext is None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1069
#    1070     with get_handle(
# -> 1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#    1073         stream = handle.handle
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/studentFrocasting/newdata/datasetPFE.xlsx'

# %%
resultfinal = pd.merge(resultf,presn, on="date")
resultfinal
# Out:
#      idRestaurant        date  Type       Plat       meteo    Event  presence
# 0          Esi016  01-09-2019  midi  Lentilles  Ensoleillé   Normal       153
# 1          Esi016  02-09-2019  midi     Loubia  Ensoleillé   Normal       153
# 2          Esi016  03-09-2019  midi        Riz  Ensoleillé   Normal       105
# 3          Esi016  04-09-2019  midi  Spaghetti  Ensoleillé   Normal        82
# 4          Esi016  05-09-2019  midi   Couscous  Ensoleillé   Normal       176
# ...           ...         ...   ...        ...         ...      ...       ...
# 1075       Esi016  11-08-2022  midi   Couscous  Ensoleillé   Normal       176
# 1076       Esi016  12-08-2022  midi    Weekend  Ensoleillé  Weekend         0
# 1077       Esi016  13-08-2022  midi    Weekend  Ensoleillé   Normal        82
# 1078       Esi016  14-08-2022  midi  Lentilles  Ensoleillé   Normal       153
# 1079       Esi016  15-08-2022  midi     Loubia  Ensoleillé   Normal       153
#
# [1080 rows x 7 columns]

# %%
table3["Plat"].replace(["Lentilles","Loubia","Riz","Spaghetti","Couscous","Weekend"],[0,1,2,3,4,5],inplace=True)
table3["meteo"].replace(["Ensoleillé","Nuageux","Mauvais"],[0,1,2],inplace=True)
table3["Event"].replace(["Normal","Weekend","Jour férié","Ramadan"],[0,1,2,3],inplace=True)
table3["Heberg"].replace(["interne","externe"],[0,1],inplace=True)
table3["Bourse"].replace(["Oui","Non"],[0,1],inplace=True)

# %%
fig, axes = plt.subplots(figsize= (10,8))
sns.heatmap(table3.corr(), annot=True, cmap='Oranges')
plt.xticks(rotation=30, ha='right')
plt.title("Matrice de corrélation")
plt.show()

# %%
table3
# Out:
#         Unnamed: 0 idRestaurant        date  Type  Plat  meteo  Event  \
# 0                0       Esi016  01-09-2019  midi     0      0      0
# 1                1       Esi016  01-09-2019  midi     0      0      0
# 2                2       Esi016  01-09-2019  midi     0      0      0
# 3                3       Esi016  01-09-2019  midi     0      0      0
# 4                4       Esi016  01-09-2019  midi     0      0      0
# ...            ...          ...         ...   ...   ...    ...    ...
# 215995      215995       Esi016  15-08-2022  midi     1      0      0
# 215996      215996       Esi016  15-08-2022  midi     1      0      0
# 215997      215997       Esi016  15-08-2022  midi     1      0      0
# 215998      215998       Esi016  15-08-2022  midi     1      0      0
# 215999      215999       Esi016  15-08-2022  midi     1      0      0
#
#        idEtudiant  Heberg  Rev_par  Bourse  presenceP  presence
# 0         17/0001       0    56879       0      0.525         0
# 1         17/0002       1    19184       0      0.705         1
# 2         17/0003       1    56879       0      0.600         1
# 3         17/0004       1    19184       0      0.705         1
# 4         17/0005       0   139936       1      0.410         0
# ...           ...     ...      ...     ...        ...       ...
# 215995    17/0196       0    25251       0      0.650         1
# 215996    17/0197       0    19184       0      0.650         1
# 215997    17/0198       0    56879       0      0.545         0
# 215998    17/0199       0    56879       0      0.545         0
# 215999    17/0200       1    46901       0      0.725         1
#
# [216000 rows x 13 columns]

# %% [markdown]
# # Construction de jeu de données

# %%
training_data = table3.sample(frac=2/3, random_state=0)
testing_data = table3.drop(training_data.index)

# %%
training_data.size
# Out:
# 1728000

# %%
testing_data.size
# Out:
# 864000

# %%
training_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-aa4368bc1598> in <module>
# ----> 1 training_data
#
# NameError: name 'training_data' is not defined

# %%
x=table3.drop(["idRestaurant","Type","idEtudiant","presenceP","presence","Unnamed: 0","meteo","Bourse"] , axis=1)   
y=table3["presence"]

# %%
x
# Out:
#               date  Plat  Event  Heberg  Rev_par
# 0       01-09-2019     0      0       0    56879
# 1       01-09-2019     0      0       1    19184
# 2       01-09-2019     0      0       1    56879
# 3       01-09-2019     0      0       1    19184
# 4       01-09-2019     0      0       0   139936
# ...            ...   ...    ...     ...      ...
# 215995  15-08-2022     1      0       0    25251
# 215996  15-08-2022     1      0       0    19184
# 215997  15-08-2022     1      0       0    56879
# 215998  15-08-2022     1      0       0    56879
# 215999  15-08-2022     1      0       1    46901
#
# [216000 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=1/3,random_state=None,shuffle = False)

# %%
X_train=X_train.drop(["date"],axis=1)

# %%
X_train
# Out:
#         Plat  Event  Heberg  Rev_par
# 0          0      0       0    56879
# 1          0      0       1    19184
# 2          0      0       1    56879
# 3          0      0       1    19184
# 4          0      0       0   139936
# ...      ...    ...     ...      ...
# 143995     5      1       0    25251
# 143996     5      1       0    19184
# 143997     5      1       0    56879
# 143998     5      1       0    56879
# 143999     5      1       1    46901
#
# [144000 rows x 4 columns]

# %%
X_test.drop(["date"],axis=1)
# Out:
#         Plat  Event  Heberg  Rev_par
# 144000     5      0       0    56879
# 144001     5      0       1    19184
# 144002     5      0       1    56879
# 144003     5      0       1    19184
# 144004     5      0       0   139936
# ...      ...    ...     ...      ...
# 215995     1      0       0    25251
# 215996     1      0       0    19184
# 215997     1      0       0    56879
# 215998     1      0       0    56879
# 215999     1      0       1    46901
#
# [72000 rows x 4 columns]

# %%
 from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
print('Score du model =', model.score(X_train,y_train ))
# Out:
# Score du model = 0.4676458333333333

# %%
cm = confusion_matrix(model.predict(X_train),y_train)
print(cm)
# Out:
# [[49846  6334]
#  [17495 70325]]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(10)

# %%
model.fit(X_train,y_train )
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
print('Coeff R2 =', model.score(X_train,y_train ))
# Out:
# Coeff R2 = 1.0

# %%
cm = confusion_matrix(model.predict(X_train),y_train)
print(cm)
# Out:
# [[70883     0]
#  [    0 80317]]

# %%
tableMod = pd.read_csv("tablePredection.csv")

# %%
tableMod=tableMod.drop(["Unnamed: 0","Unnamed: 0.1"],axis=1)

# %%
tableMod
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse  presenceP  presence
# 0         17/0001  interne    56879    Oui      0.525         0
# 1         17/0002  externe    19184    Oui      0.705         1
# 2         17/0003  externe    56879    Oui      0.600         1
# 3         17/0004  externe    19184    Oui      0.705         1
# 4         17/0005  interne   139936    Non      0.410         0
# ...           ...      ...      ...    ...        ...       ...
# 215995    17/0196  interne    25251    Oui      0.650         1
# 215996    17/0197  interne    19184    Oui      0.650         1
# 215997    17/0198  interne    56879    Oui      0.545         0
# 215998    17/0199  interne    56879    Oui      0.545         0
# 215999    17/0200  externe    46901    Oui      0.725         1
#
# [216000 rows x 12 columns]

# %%
for i in range(216000):
    tableMod["presence"][i] = decide(tableMod["presenceP"][i])
# Out:
# <ipython-input-68-49da3f113eed>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableMod["presence"][i] = decide(tableMod["presenceP"][i])

# %%
tableMod
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse  presenceP  presence
# 0         17/0001  interne    56879    Oui      0.525         1
# 1         17/0002  externe    19184    Oui      0.705         0
# 2         17/0003  externe    56879    Oui      0.600         0
# 3         17/0004  externe    19184    Oui      0.705         1
# 4         17/0005  interne   139936    Non      0.410         0
# ...           ...      ...      ...    ...        ...       ...
# 215995    17/0196  interne    25251    Oui      0.650         1
# 215996    17/0197  interne    19184    Oui      0.650         1
# 215997    17/0198  interne    56879    Oui      0.545         1
# 215998    17/0199  interne    56879    Oui      0.545         0
# 215999    17/0200  externe    46901    Oui      0.725         0
#
# [216000 rows x 12 columns]

# %%
tableSum=tableMod.groupby(['date'],as_index=False).sum()
tableSum=tableSum.drop(['Rev_par','presenceP'], axis=1)

# %%
tableSum.to_excel("NbPresence.xlsx")

# %%
nbpres = pd.read_excel("NbPresence.xlsx")
nbpres
# Out:
#            date  presence
# 0    2019-09-01       118
# 1    2019-09-02       137
# 2    2019-09-03       115
# 3    2019-09-04       110
# 4    2019-09-05       139
# ...         ...       ...
# 1075 2022-08-11       126
# 1076 2022-08-12         0
# 1077 2022-08-13       104
# 1078 2022-08-14       136
# 1079 2022-08-15       134
#
# [1080 rows x 2 columns]

# %%
f,ax = plt.subplots(1,1,figsize=(20,8))
plt1=nbpres.set_index('date')
plt1.plot(color='salmon', kind='area', ax=ax)
plt.ylabel("Total des présents")
plt.title("Répartitions des présents par date")
# Out:
# Text(0.5, 1.0, 'Répartitions des présents par date')

# %% [markdown]
# # Time series

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib.pylab import rcParams

# %%
nbpres['date'] = pd.to_datetime(nbpres['date'],infer_datetime_format=True) #convert from string to datetime
indexedDataset = nbpres.set_index(['date'])
indexedDataset.head(5)
# Out:
#             presence
# date
# 2019-09-01       617
# 2019-09-02       620
# 2019-09-03       585
# 2019-09-04       604
# 2019-09-05       702

# %%
plt.xlabel('Date')
plt.ylabel('Number of presents')
plt.plot(indexedDataset)

# %%
rolmean = indexedDataset.rolling(window=7).mean() #window size 12 denotes 12 months, giving rolling mean at yearly level
rolstd = indexedDataset.rolling(window=7).std()
print(rolmean,rolstd)
# Out:
#               presence
# date
# 2019-09-01         NaN
# 2019-09-02         NaN
# 2019-09-03         NaN
# 2019-09-04         NaN
# 2019-09-05         NaN
# ...                ...
# 2022-08-11  424.857143
# 2022-08-12  424.857143
# 2022-08-13  425.571429
# 2022-08-14  516.000000
# 2022-08-15  521.571429
#
# [1080 rows x 1 columns]               presence
# date
# 2019-09-01         NaN
# 2019-09-02         NaN
# 2019-09-03         NaN
# 2019-09-04         NaN
# 2019-09-05         NaN
# ...                ...
# 2022-08-11  295.922528
# 2022-08-12  295.922528
# 2022-08-13  296.134461
# 2022-08-14  234.821918
# 2022-08-15  238.058016
#
# [1080 rows x 1 columns]

# %%
#Plot rolling statistics
plt.figure(figsize=(15,7))
orig = plt.plot(indexedDataset, color='blue', label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
print('Results of Dickey Fuller Test:')
dftest = adfuller(indexedDataset['presence'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                   -4.959693
# p-value                           0.000027
# #Lags Used                       22.000000
# Number of Observations Used    1057.000000
# Critical Value (1%)              -3.436552
# Critical Value (5%)              -2.864278
# Critical Value (10%)             -2.568228
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})


# Original Series
fig, axes = plt.subplots(3, 2, sharex=False)
axes[0, 0].plot(indexedDataset.presence); axes[0, 0].set_title('Original Series')
plot_acf(indexedDataset.presence, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(indexedDataset.presence.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(indexedDataset.presence.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(indexedDataset.presence.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(indexedDataset.presence.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=False)
axes[0].plot(indexedDataset.presence); axes[0].set_title('no Differencing')
#axes[1].set(ylim=(-1,1))
plot_pacf(indexedDataset.presence.dropna(), ax=axes[1])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=False)
axes[0].plot(indexedDataset.presence); axes[0].set_title('no Differencing')
plot_acf(indexedDataset.presence.dropna(), ax=axes[1])

plt.show()

# %%
import statsmodels.api as sm

# 1,0,2 ARIMA Model
model = sm.tsa.arima.ARIMA(indexedDataset.presence, order=(1,0,2))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                 1080
# Model:                 ARIMA(1, 0, 2)   Log Likelihood               -7550.943
# Date:                Mon, 25 Jul 2022   AIC                          15111.887
# Time:                        16:34:53   BIC                          15136.810
# Sample:                    09-01-2019   HQIC                         15121.324
#                          - 08-15-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        440.4266     75.280      5.851      0.000     292.880     587.973
# ar.L1          0.9442      0.032     29.926      0.000       0.882       1.006
# ma.L1         -0.7623      0.038    -19.864      0.000      -0.838      -0.687
# ma.L2         -0.0034      0.042     -0.082      0.935      -0.085       0.078
# sigma2      6.921e+04   1.03e+04      6.727      0.000     4.9e+04    8.94e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               216.19
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.97   Skew:                            -1.09
# Prob(H) (two-sided):                  0.79   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# 1,1,1 ARIMA Model
model = sm.tsa.arima.ARIMA(indexedDataset.presence, order=(1,0,1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                 1080
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -7550.950
# Date:                Mon, 25 Jul 2022   AIC                          15109.900
# Time:                        16:40:30   BIC                          15129.838
# Sample:                    09-01-2019   HQIC                         15117.449
#                          - 08-15-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        440.4279     72.738      6.055      0.000     297.865     582.991
# ar.L1          0.9440      0.032     29.873      0.000       0.882       1.006
# ma.L1         -0.7648      0.029    -26.159      0.000      -0.822      -0.707
# sigma2      6.921e+04      1e+04      6.891      0.000    4.95e+04    8.89e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               215.54
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.97   Skew:                            -1.09
# Prob(H) (two-sided):                  0.79   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
model_fit.plot_predict(dynamic=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-e6e523091cdc> in <module>()
# ----> 1 model_fit.plot_predict(dynamic=False)
#       2 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      32             pass
#      33
# ---> 34         obj = getattr(results, attr)
#      35         data = results.model.data
#      36         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'ARIMAResults' object has no attribute 'plot_predict'

# %%
model_fit.predict()
# Out:
# 2019-09-01    440.427880
# 2019-09-02    502.797336
# 2019-09-03    530.830942
# 2019-09-04    538.133301
# 2019-09-05    546.284353
#                  ...
# 2022-08-11    474.929632
# 2022-08-12    512.246242
# 2022-08-13    416.443482
# 2022-08-14    433.295764
# 2022-08-15    469.475937
# Freq: D, Name: predicted_mean, Length: 1080, dtype: float64

# %%
train = indexedDataset.presence[:720]
test = indexedDataset.presence[720:]

# %%
test
# Out:
# date
# 2021-08-21    494
# 2021-08-22    612
# 2021-08-23    663
# 2021-08-24    598
# 2021-08-25    573
#              ...
# 2022-08-11    694
# 2022-08-12      0
# 2022-08-13    503
# 2022-08-14    633
# 2022-08-15    656
# Name: presence, Length: 360, dtype: int64

# %%
model = sm.tsa.arima.ARIMA(train, order=(1, 0, 1))  
fitted = model.fit()  
print(fitted.summary())

# Forecast
fc, se, conf = fitted.forecast()  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                  720
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -5039.755
# Date:                Mon, 25 Jul 2022   AIC                          10087.510
# Time:                        16:59:45   BIC                          10105.827
# Sample:                    09-01-2019   HQIC                         10094.581
#                          - 08-20-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        438.2116     82.059      5.340      0.000     277.379     599.044
# ar.L1          0.9324      0.043     21.700      0.000       0.848       1.017
# ma.L1         -0.7401      0.039    -18.904      0.000      -0.817      -0.663
# sigma2      7.032e+04   1.29e+04      5.465      0.000    4.51e+04    9.55e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.26   Jarque-Bera (JB):               135.47
# Prob(Q):                              0.61   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.96   Skew:                            -1.06
# Prob(H) (two-sided):                  0.78   Kurtosis:                         3.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-5722248904ad> in <module>()
#       4
#       5 # Forecast
# ----> 6 fc, se, conf = fitted.forecast()  # 95% conf
#       7
#       8 # Make as pandas series
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
model = sm.tsa.arima.ARIMA(train, order=(3, 0, 1))  
fitted = model.fit()  
print(fitted.summary())

# Forecast
fc, se, conf = fitted.forecast(alpha=0.05)  # 95% conf


# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                  720
# Model:                 ARIMA(3, 0, 1)   Log Likelihood               -5039.527
# Date:                Mon, 25 Jul 2022   AIC                          10091.053
# Time:                        14:05:50   BIC                          10118.529
# Sample:                    09-01-2019   HQIC                         10101.661
#                          - 08-20-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        438.2130     87.125      5.030      0.000     267.452     608.974
# ar.L1          0.9662      0.097      9.976      0.000       0.776       1.156
# ar.L2         -0.0332      0.066     -0.499      0.618      -0.163       0.097
# ar.L3          0.0039      0.060      0.066      0.948      -0.113       0.121
# ma.L1         -0.7550      0.076     -9.898      0.000      -0.905      -0.606
# sigma2      7.027e+04   1.34e+04      5.256      0.000    4.41e+04    9.65e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               137.80
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.97   Skew:                            -1.07
# Prob(H) (two-sided):                  0.78   Kurtosis:                         3.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-ca24cebe886a> in <module>()
#       4
#       5 # Forecast
# ----> 6 fc, se, conf = fitted.forecast(alpha=0.05)  # 95% conf
#       7
#       8
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    acf1 = acf(fc-test)[1]                      # ACF1
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'acf1':acf1, 
            'corr':corr, 'minmax':minmax})

forecast_accuracy(fc, test.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-901c04103e5c> in <module>()
#      16             'corr':corr, 'minmax':minmax})
#      17
# ---> 18 forecast_accuracy(fc, test.values)
#
# NameError: name 'fc' is not defined

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.7/dist-packages (1.8.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.30)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.9)

# %%
from statsmodels.tsa.arima_model import ARIMA

import pmdarima as pm

model = pm.auto_arima(indexedDataset.presence, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=15, max_q=6, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=1,
                      start_Q=1,
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5196186508c5> in <module>()
#       3 import pmdarima as pm
#       4
# ----> 5 model = pm.auto_arima(indexedDataset.presence, start_p=1, start_q=1,
#       6                       test='adf',       # use adftest to find optimal 'd'
#       7                       max_p=15, max_q=6, # maximum p and q
#
# NameError: name 'indexedDataset' is not defined

# %%
model = ARIMA(train, order=(10, 0, 6))  
fitted = model.fit(disp=-1)  
print(fitted.summary())

# Forecast
fc, se, conf = fitted.forecast(360, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                  720
# Model:                    ARMA(10, 6)   Log Likelihood               -3443.198
# Method:                       css-mle   S.D. of innovations             28.559
# Date:                Thu, 26 May 2022   AIC                           6922.395
# Time:                        20:57:22   BIC                           7004.822
# Sample:                    09-01-2019   HQIC                          6954.216
#                          - 08-20-2021
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              92.0236      6.700     13.734      0.000      78.891     105.156
# ar.L1.presence     -0.5949      0.056    -10.609      0.000      -0.705      -0.485
# ar.L2.presence     -0.5313      0.043    -12.268      0.000      -0.616      -0.446
# ar.L3.presence     -0.2556      0.050     -5.127      0.000      -0.353      -0.158
# ar.L4.presence     -0.1468      0.034     -4.374      0.000      -0.213      -0.081
# ar.L5.presence     -0.1517      0.033     -4.538      0.000      -0.217      -0.086
# ar.L6.presence     -0.1424      0.033     -4.254      0.000      -0.208      -0.077
# ar.L7.presence      0.8457      0.034     25.240      0.000       0.780       0.911
# ar.L8.presence      0.4501      0.060      7.465      0.000       0.332       0.568
# ar.L9.presence      0.3789      0.038      9.888      0.000       0.304       0.454
# ar.L10.presence     0.1078      0.045      2.410      0.016       0.020       0.195
# ma.L1.presence      0.8697      0.043     20.169      0.000       0.785       0.954
# ma.L2.presence      0.9492      0.002    400.731      0.000       0.945       0.954
# ma.L3.presence      0.8989      0.034     26.820      0.000       0.833       0.965
# ma.L4.presence      0.8495      0.037     22.714      0.000       0.776       0.923
# ma.L5.presence      0.9152      0.027     33.428      0.000       0.862       0.969
# ma.L6.presence      0.8172      0.041     20.113      0.000       0.738       0.897
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             1.0778           -0.0000j            1.0778           -0.0000
# AR.2             0.6235           -0.7821j            1.0002           -0.1429
# AR.3             0.6235           +0.7821j            1.0002            0.1429
# AR.4            -0.2228           -0.9750j            1.0001           -0.2858
# AR.5            -0.2228           +0.9750j            1.0001            0.2858
# AR.6            -0.9045           -0.4354j            1.0038           -0.4286
# AR.7            -0.9045           +0.4354j            1.0038            0.4286
# AR.8            -0.2793           -1.6558j            1.6792           -0.2766
# AR.9            -0.2793           +1.6558j            1.6792            0.2766
# AR.10           -3.0277           -0.0000j            3.0277           -0.5000
# MA.1             0.6343           -0.7933j            1.0157           -0.1426
# MA.2             0.6343           +0.7933j            1.0157            0.1426
# MA.3            -0.2190           -0.9828j            1.0069           -0.2849
# MA.4            -0.2190           +0.9828j            1.0069            0.2849
# MA.5            -0.9752           -0.4677j            1.0816           -0.4288
# MA.6            -0.9752           +0.4677j            1.0816            0.4288
# ------------------------------------------------------------------------------

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
arima_model = SARIMAX(train, order = (2,1,1), seasonal_order = (4,0,3,12))
arima_result = arima_model.fit()
arima_result.summary()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ==================================================================================================
# Dep. Variable:                                   presence   No. Observations:                  720
# Model:             SARIMAX(2, 1, 1)x(4, 0, [1, 2, 3], 12)   Log Likelihood               -3774.772
# Date:                                    Thu, 26 May 2022   AIC                           7571.545
# Time:                                            21:25:41   BIC                           7621.901
# Sample:                                        09-01-2019   HQIC                          7590.986
#                                              - 08-20-2021
# Covariance Type:                                      opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2624      0.076      3.445      0.001       0.113       0.412
# ar.L2         -0.2148      0.069     -3.128      0.002      -0.349      -0.080
# ma.L1         -0.8449      0.044    -19.113      0.000      -0.932      -0.758
# ar.S.L12      -0.0324      0.113     -0.287      0.774      -0.253       0.189
# ar.S.L24       0.2624      0.105      2.510      0.012       0.057       0.467
# ar.S.L36      -0.8422      0.083    -10.180      0.000      -1.004      -0.680
# ar.S.L48      -0.3532      0.070     -5.075      0.000      -0.490      -0.217
# ma.S.L12      -0.2756      0.107     -2.567      0.010      -0.486      -0.065
# ma.S.L24      -0.2103      0.111     -1.897      0.058      -0.428       0.007
# ma.S.L36       0.9203      0.119      7.704      0.000       0.686       1.154
# sigma2      2882.8067    245.153     11.759      0.000    2402.316    3363.298
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.88   Jarque-Bera (JB):               135.49
# Prob(Q):                              0.35   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.11   Skew:                            -0.97
# Prob(H) (two-sided):                  0.40   Kurtosis:                         3.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
arima_pred = arima_result.predict(start = len(train), end = len(indexedDataset)-1, typ="levels").rename("ARIMA Predictions")
arima_pred
# Out:
# 2021-08-21    104.527526
# 2021-08-22    124.997783
# 2021-08-23     76.712617
# 2021-08-24     90.530259
# 2021-08-25     78.106932
#                  ...
# 2022-08-11    117.230540
# 2022-08-12     55.329335
# 2022-08-13    108.188191
# 2022-08-14     75.989113
# 2022-08-15     75.214630
# Freq: D, Name: ARIMA Predictions, Length: 360, dtype: float64

# %%
test.plot(figsize = (16,5), legend=True)
arima_pred.plot(legend = True);

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
arima_rmse_error = rmse(test, arima_pred)
arima_mse_error = arima_rmse_error**2
mean_value = indexedDataset.presence.mean()

print(f'MSE Error: {arima_mse_error}\nRMSE Error: {arima_rmse_error}\nMean: {mean_value}')
# Out:
# MSE Error: 3063.7028949965993
# RMSE Error: 55.35072623730062
# Mean: 97.14907407407408

# %% [markdown]
# # LSTM

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
train = train.values.reshape(-1,1)

# %%
test = test.values.reshape(-1,1)

# %%
scaler.fit(train)
scaled_train_data = scaler.transform(train)
scaled_test_data = scaler.transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

n_input = 12
n_features= 1
generator = TimeseriesGenerator(scaled_train_data, scaled_train_data, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

lstm_model = Sequential()
lstm_model.add(LSTM(200, activation='relu', input_shape=(n_input, n_features)))
lstm_model.add(Dense(1))
lstm_model.compile(optimizer='adam', loss='mse')

lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 200)               161600
#
#  dense (Dense)               (None, 1)                 201
#
# =================================================================
# Total params: 161,801
# Trainable params: 161,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit_generator(generator,epochs=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """Entry point for launching an IPython kernel.
# Epoch 1/20
# 708/708 [==============================] - 9s 9ms/step - loss: 0.1327
# Epoch 2/20
# 708/708 [==============================] - 6s 8ms/step - loss: 0.1159
# Epoch 3/20
# 708/708 [==============================] - 6s 8ms/step - loss: 0.1061
# Epoch 4/20
# 708/708 [==============================] - 6s 8ms/step - loss: 0.0873
# Epoch 5/20
# 708/708 [==============================] - 6s 9ms/step - loss: 0.0732
# Epoch 6/20
# 708/708 [==============================] - 6s 8ms/step - loss: 0.0613
# Epoch 7/20
# 708/708 [==============================] - 6s 8ms/step - loss: 0.0559
# Epoch 8/20
# 708/708 [==============================] - 6s 8ms/step - loss: 0.0515
# Epoch 9/20
# 708/708 [==============================] - 6s 8ms/step - loss: 0.0494
# Epoch 10/20
# 708/708 [==============================] - 7s 10ms/step - loss: 0.0468
# Epoch 11/20
# 708/708 [==============================] - 6s 9ms/step - loss: 0.0450
# Epoch 12/20
# 708/708 [==============================] - 6s 8ms/step - loss: 0.0444
# Epoch 13/20
# 708/708 [==============================] - 6s 9ms/step - loss: 0.0429
# Epoch 14/20
# 708/708 [==============================] - 6s 9ms/step - loss: 0.0423
# Epoch 15/20
# 708/708 [==============================] - 6s 8ms/step - loss: 0.0409
# Epoch 16/20
# 708/708 [==============================] - 6s 9ms/step - loss: 0.0406
# Epoch 17/20
# 708/708 [==============================] - 6s 9ms/step - loss: 0.0392
# Epoch 18/20
# 708/708 [==============================] - 6s 9ms/step - loss: 0.0382
# Epoch 19/20
# 708/708 [==============================] - 6s 8ms/step - loss: 0.0399
# Epoch 20/20
# 708/708 [==============================] - 6s 8ms/step - loss: 0.0382

# %%
losses_lstm = lstm_model.history.history['loss']
plt.figure(figsize=(12,4))
plt.xticks(np.arange(0,21,1))
plt.plot(range(len(losses_lstm)),losses_lstm);

# %%
lstm_predictions_scaled = list()

batch = scaled_train_data[-n_input:]
current_batch = batch.reshape((1, n_input, n_features))

for i in range(len(test)):   
    lstm_pred = lstm_model.predict(current_batch)[0]
    lstm_predictions_scaled.append(lstm_pred) 
    current_batch = np.append(current_batch[:,1:,:],[[lstm_pred]],axis=1)

# %%
lstm_predictions_scaled
# Out:
# [array([0.26425654], dtype=float32),
#  array([0.33839104], dtype=float32),
#  array([0.41260463], dtype=float32),
#  array([0.4669781], dtype=float32),
#  array([0.5145607], dtype=float32),
#  array([0.45200476], dtype=float32),
#  array([0.3084934], dtype=float32),
#  array([0.41939414], dtype=float32),
#  array([0.4914255], dtype=float32),
#  array([0.5189929], dtype=float32),
#  array([0.5526298], dtype=float32),
#  array([0.5938115], dtype=float32),
#  array([0.5884141], dtype=float32),
#  array([0.3506783], dtype=float32),
#  array([0.4189204], dtype=float32),
#  array([0.4619948], dtype=float32),
#  array([0.5441218], dtype=float32),
#  array([0.5884992], dtype=float32),
#  array([0.62708956], dtype=float32),
#  array([0.5995833], dtype=float32),
#  array([0.32536414], dtype=float32),
#  array([0.4107504], dtype=float32),
#  array([0.4590369], dtype=float32),
#  array([0.5494424], dtype=float32),
#  array([0.5923309], dtype=float32),
#  array([0.6322124], dtype=float32),
#  array([0.61557686], dtype=float32),
#  array([0.31217238], dtype=float32),
#  array([0.41577274], dtype=float32),
#  array([0.47235465], dtype=float32),
#  array([0.5554443], dtype=float32),
#  array([0.59643716], dtype=float32),
#  array([0.63547623], dtype=float32),
#  array([0.62341595], dtype=float32),
#  array([0.29985902], dtype=float32),
#  array([0.42295074], dtype=float32),
#  array([0.48291346], dtype=float32),
#  array([0.5620288], dtype=float32),
#  array([0.6011873], dtype=float32),
#  array([0.6391549], dtype=float32),
#  array([0.6265707], dtype=float32),
#  array([0.28840956], dtype=float32),
#  array([0.42834848], dtype=float32),
#  array([0.492225], dtype=float32),
#  array([0.5675144], dtype=float32),
#  array([0.60525405], dtype=float32),
#  array([0.64216876], dtype=float32),
#  array([0.6283389], dtype=float32),
#  array([0.2808364], dtype=float32),
#  array([0.43192422], dtype=float32),
#  array([0.49869797], dtype=float32),
#  array([0.5714414], dtype=float32),
#  array([0.6080837], dtype=float32),
#  array([0.64408875], dtype=float32),
#  array([0.6292229], dtype=float32),
#  array([0.27557537], dtype=float32),
#  array([0.4342804], dtype=float32),
#  array([0.5028925], dtype=float32),
#  array([0.5742965], dtype=float32),
#  array([0.6100512], dtype=float32),
#  array([0.64521307], dtype=float32),
#  array([0.6297765], dtype=float32),
#  array([0.27229196], dtype=float32),
#  array([0.43587607], dtype=float32),
#  array([0.5057397], dtype=float32),
#  array([0.5762177], dtype=float32),
#  array([0.6113821], dtype=float32),
#  array([0.64596415], dtype=float32),
#  array([0.6300695], dtype=float32),
#  array([0.27004656], dtype=float32),
#  array([0.4369253], dtype=float32),
#  array([0.50774485], dtype=float32),
#  array([0.5775346], dtype=float32),
#  array([0.6123042], dtype=float32),
#  array([0.6465041], dtype=float32),
#  array([0.6302404], dtype=float32),
#  array([0.2679043], dtype=float32),
#  array([0.4378549], dtype=float32),
#  array([0.5095117], dtype=float32),
#  array([0.57866454], dtype=float32),
#  array([0.6131009], dtype=float32),
#  array([0.6470095], dtype=float32),
#  array([0.6304562], dtype=float32),
#  array([0.26626772], dtype=float32),
#  array([0.4386356], dtype=float32),
#  array([0.510968], dtype=float32),
#  array([0.57958674], dtype=float32),
#  array([0.61375546], dtype=float32),
#  array([0.6474085], dtype=float32),
#  array([0.6306163], dtype=float32),
#  array([0.2649638], dtype=float32),
#  array([0.43924385], dtype=float32),
#  array([0.5121078], dtype=float32),
#  array([0.58032024], dtype=float32),
#  array([0.61427444], dtype=float32),
#  array([0.6477264], dtype=float32),
#  array([0.63073456], dtype=float32),
#  array([0.26391593], dtype=float32),
#  array([0.43972343], dtype=float32),
#  array([0.51302046], dtype=float32),
#  array([0.5809037], dtype=float32),
#  array([0.6146859], dtype=float32),
#  array([0.6479795], dtype=float32),
#  array([0.6308315], dtype=float32),
#  array([0.26308176], dtype=float32),
#  array([0.44010687], dtype=float32),
#  array([0.5138608], dtype=float32),
#  array([0.5814039], dtype=float32),
#  array([0.6150432], dtype=float32),
#  array([0.64820766], dtype=float32),
#  array([0.6309093], dtype=float32),
#  array([0.26241648], dtype=float32),
#  array([0.44042224], dtype=float32),
#  array([0.5145389], dtype=float32),
#  array([0.581813], dtype=float32),
#  array([0.6153381], dtype=float32),
#  array([0.6484014], dtype=float32),
#  array([0.63097], dtype=float32),
#  array([0.26185668], dtype=float32),
#  array([0.44068107], dtype=float32),
#  array([0.51509917], dtype=float32),
#  array([0.58215135], dtype=float32),
#  array([0.61558187], dtype=float32),
#  array([0.6485658], dtype=float32),
#  array([0.6310222], dtype=float32),
#  array([0.26139334], dtype=float32),
#  array([0.44089603], dtype=float32),
#  array([0.5155648], dtype=float32),
#  array([0.5824318], dtype=float32),
#  array([0.6157835], dtype=float32),
#  array([0.6487019], dtype=float32),
#  array([0.6310679], dtype=float32),
#  array([0.2610091], dtype=float32),
#  array([0.44107497], dtype=float32),
#  array([0.51595145], dtype=float32),
#  array([0.5826651], dtype=float32),
#  array([0.6159514], dtype=float32),
#  array([0.6488152], dtype=float32),
#  array([0.6311089], dtype=float32),
#  array([0.2606886], dtype=float32),
#  array([0.441225], dtype=float32),
#  array([0.5162746], dtype=float32),
#  array([0.58286023], dtype=float32),
#  array([0.61609185], dtype=float32),
#  array([0.6489103], dtype=float32),
#  array([0.6311439], dtype=float32),
#  array([0.2604211], dtype=float32),
#  array([0.44135022], dtype=float32),
#  array([0.51654434], dtype=float32),
#  array([0.5830231], dtype=float32),
#  array([0.61620903], dtype=float32),
#  array([0.6489896], dtype=float32),
#  array([0.6311734], dtype=float32),
#  array([0.26019973], dtype=float32),
#  array([0.4414542], dtype=float32),
#  array([0.51676804], dtype=float32),
#  array([0.58315814], dtype=float32),
#  array([0.61630625], dtype=float32),
#  array([0.64905536], dtype=float32),
#  array([0.63119745], dtype=float32),
#  array([0.26003557], dtype=float32),
#  array([0.4415333], dtype=float32),
#  array([0.51694024], dtype=float32),
#  array([0.58326244], dtype=float32),
#  array([0.6163811], dtype=float32),
#  array([0.6491051], dtype=float32),
#  array([0.6312142], dtype=float32),
#  array([0.25990587], dtype=float32),
#  array([0.441594], dtype=float32),
#  array([0.5170733], dtype=float32),
#  array([0.58334345], dtype=float32),
#  array([0.61643934], dtype=float32),
#  array([0.64914393], dtype=float32),
#  array([0.63122743], dtype=float32),
#  array([0.25980496], dtype=float32),
#  array([0.4416414], dtype=float32),
#  array([0.5171775], dtype=float32),
#  array([0.58340645], dtype=float32),
#  array([0.6164846], dtype=float32),
#  array([0.6491743], dtype=float32),
#  array([0.63123786], dtype=float32),
#  array([0.25972676], dtype=float32),
#  array([0.4416783], dtype=float32),
#  array([0.51725817], dtype=float32),
#  array([0.5834553], dtype=float32),
#  array([0.6165199], dtype=float32),
#  array([0.6491977], dtype=float32),
#  array([0.63124573], dtype=float32),
#  array([0.25966582], dtype=float32),
#  array([0.44170672], dtype=float32),
#  array([0.517321], dtype=float32),
#  array([0.58349335], dtype=float32),
#  array([0.6165469], dtype=float32),
#  array([0.64921594], dtype=float32),
#  array([0.63125205], dtype=float32),
#  array([0.25961843], dtype=float32),
#  array([0.44172913], dtype=float32),
#  array([0.5173699], dtype=float32),
#  array([0.583523], dtype=float32),
#  array([0.6165683], dtype=float32),
#  array([0.6492302], dtype=float32),
#  array([0.63125694], dtype=float32),
#  array([0.25958169], dtype=float32),
#  array([0.44174647], dtype=float32),
#  array([0.5174079], dtype=float32),
#  array([0.58354604], dtype=float32),
#  array([0.6165849], dtype=float32),
#  array([0.6492412], dtype=float32),
#  array([0.6312609], dtype=float32),
#  array([0.2595529], dtype=float32),
#  array([0.4417601], dtype=float32),
#  array([0.5174376], dtype=float32),
#  array([0.58356404], dtype=float32),
#  array([0.61659783], dtype=float32),
#  array([0.6492498], dtype=float32),
#  array([0.63126373], dtype=float32),
#  array([0.25953054], dtype=float32),
#  array([0.4417706], dtype=float32),
#  array([0.51746064], dtype=float32),
#  array([0.583578], dtype=float32),
#  array([0.6166079], dtype=float32),
#  array([0.6492566], dtype=float32),
#  array([0.6312661], dtype=float32),
#  array([0.25951314], dtype=float32),
#  array([0.44177875], dtype=float32),
#  array([0.5174786], dtype=float32),
#  array([0.58358884], dtype=float32),
#  array([0.61661565], dtype=float32),
#  array([0.6492618], dtype=float32),
#  array([0.63126785], dtype=float32),
#  array([0.2594997], dtype=float32),
#  array([0.44178516], dtype=float32),
#  array([0.5174924], dtype=float32),
#  array([0.5835973], dtype=float32),
#  array([0.61662173], dtype=float32),
#  array([0.6492659], dtype=float32),
#  array([0.6312692], dtype=float32),
#  array([0.25948936], dtype=float32),
#  array([0.44179], dtype=float32),
#  array([0.51750326], dtype=float32),
#  array([0.58360386], dtype=float32),
#  array([0.6166265], dtype=float32),
#  array([0.649269], dtype=float32),
#  array([0.63127023], dtype=float32),
#  array([0.25948113], dtype=float32),
#  array([0.44179368], dtype=float32),
#  array([0.5175116], dtype=float32),
#  array([0.58360887], dtype=float32),
#  array([0.61662996], dtype=float32),
#  array([0.6492713], dtype=float32),
#  array([0.63127106], dtype=float32),
#  array([0.25947472], dtype=float32),
#  array([0.44179678], dtype=float32),
#  array([0.51751804], dtype=float32),
#  array([0.5836128], dtype=float32),
#  array([0.6166328], dtype=float32),
#  array([0.6492733], dtype=float32),
#  array([0.6312717], dtype=float32),
#  array([0.25946987], dtype=float32),
#  array([0.44179922], dtype=float32),
#  array([0.5175233], dtype=float32),
#  array([0.583616], dtype=float32),
#  array([0.6166351], dtype=float32),
#  array([0.6492747], dtype=float32),
#  array([0.6312722], dtype=float32),
#  array([0.2594661], dtype=float32),
#  array([0.44180095], dtype=float32),
#  array([0.5175272], dtype=float32),
#  array([0.5836184], dtype=float32),
#  array([0.6166369], dtype=float32),
#  array([0.6492759], dtype=float32),
#  array([0.63127255], dtype=float32),
#  array([0.25946316], dtype=float32),
#  array([0.44180232], dtype=float32),
#  array([0.5175301], dtype=float32),
#  array([0.5836202], dtype=float32),
#  array([0.61663806], dtype=float32),
#  array([0.64927673], dtype=float32),
#  array([0.631273], dtype=float32),
#  array([0.2594607], dtype=float32),
#  array([0.44180346], dtype=float32),
#  array([0.5175327], dtype=float32),
#  array([0.5836216], dtype=float32),
#  array([0.61663926], dtype=float32),
#  array([0.64927745], dtype=float32),
#  array([0.6312732], dtype=float32),
#  array([0.2594588], dtype=float32),
#  array([0.4418043], dtype=float32),
#  array([0.5175347], dtype=float32),
#  array([0.5836228], dtype=float32),
#  array([0.6166401], dtype=float32),
#  array([0.6492781], dtype=float32),
#  array([0.6312733], dtype=float32),
#  array([0.25945753], dtype=float32),
#  array([0.44180492], dtype=float32),
#  array([0.51753604], dtype=float32),
#  array([0.58362365], dtype=float32),
#  array([0.61664075], dtype=float32),
#  array([0.64927846], dtype=float32),
#  array([0.63127357], dtype=float32),
#  array([0.2594564], dtype=float32),
#  array([0.44180545], dtype=float32),
#  array([0.5175371], dtype=float32),
#  array([0.58362436], dtype=float32),
#  array([0.61664116], dtype=float32),
#  array([0.64927876], dtype=float32),
#  array([0.6312736], dtype=float32),
#  array([0.25945562], dtype=float32),
#  array([0.44180578], dtype=float32),
#  array([0.51753795], dtype=float32),
#  array([0.58362484], dtype=float32),
#  array([0.6166415], dtype=float32),
#  array([0.6492791], dtype=float32),
#  array([0.63127375], dtype=float32),
#  array([0.25945497], dtype=float32),
#  array([0.44180614], dtype=float32),
#  array([0.51753867], dtype=float32),
#  array([0.5836252], dtype=float32),
#  array([0.6166418], dtype=float32),
#  array([0.64927924], dtype=float32),
#  array([0.63127387], dtype=float32),
#  array([0.25945452], dtype=float32),
#  array([0.4418062], dtype=float32),
#  array([0.517539], dtype=float32),
#  array([0.58362544], dtype=float32),
#  array([0.6166419], dtype=float32),
#  array([0.64927936], dtype=float32),
#  array([0.6312739], dtype=float32),
#  array([0.25945398], dtype=float32),
#  array([0.44180655], dtype=float32),
#  array([0.5175395], dtype=float32),
#  array([0.58362573], dtype=float32),
#  array([0.6166421], dtype=float32),
#  array([0.6492795], dtype=float32),
#  array([0.6312739], dtype=float32),
#  array([0.25945377], dtype=float32),
#  array([0.4418066], dtype=float32),
#  array([0.5175397], dtype=float32),
#  array([0.5836258], dtype=float32),
#  array([0.61664224], dtype=float32),
#  array([0.64927953], dtype=float32),
#  array([0.6312739], dtype=float32),
#  array([0.2594535], dtype=float32),
#  array([0.4418068], dtype=float32),
#  array([0.51754004], dtype=float32),
#  array([0.5836261], dtype=float32),
#  array([0.6166424], dtype=float32),
#  array([0.6492796], dtype=float32),
#  array([0.631274], dtype=float32),
#  array([0.2594534], dtype=float32),
#  array([0.44180676], dtype=float32),
#  array([0.5175402], dtype=float32),
#  array([0.5836263], dtype=float32),
#  array([0.61664253], dtype=float32),
#  array([0.6492797], dtype=float32),
#  array([0.6312741], dtype=float32),
#  array([0.25945318], dtype=float32),
#  array([0.44180697], dtype=float32),
#  array([0.51754045], dtype=float32),
#  array([0.5836264], dtype=float32)]

# %%
lstm_predictions = scaler.inverse_transform(lstm_predictions_scaled)

# %%
lstm_predictions
# Out:
# array([[207.44138151],
#        [265.6369631 ],
#        [323.89463454],
#        [366.57781079],
#        [403.93014908],
#        [354.823737  ],
#        [242.16732338],
#        [329.22439635],
#        [385.76902866],
#        [407.40942717],
#        [433.81441534],
#        [466.14203691],
#        [461.9050473 ],
#        [275.28246149],
#        [328.85251224],
#        [362.66591564],
#        [427.13561445],
#        [461.97186291],
#        [492.26530463],
#        [470.6729123 ],
#        [255.41085199],
#        [322.43905544],
#        [360.34395605],
#        [431.31229222],
#        [464.97973531],
#        [496.28673434],
#        [483.22783768],
#        [245.05532071],
#        [326.38159782],
#        [370.79840064],
#        [436.02377564],
#        [468.20316762],
#        [498.84884179],
#        [489.38151836],
#        [235.38932845],
#        [332.01633453],
#        [379.08706948],
#        [441.19262785],
#        [471.93202168],
#        [501.73660517],
#        [491.85800076],
#        [226.40150532],
#        [336.2535581 ],
#        [386.39661819],
#        [445.49881935],
#        [475.12443244],
#        [504.10247684],
#        [493.24601561],
#        [220.45657665],
#        [339.06051576],
#        [391.47790357],
#        [448.5815084 ],
#        [477.34572411],
#        [505.60966492],
#        [493.93999964],
#        [216.32666513],
#        [340.91011047],
#        [394.77060795],
#        [450.82273245],
#        [478.89020354],
#        [506.49225801],
#        [494.37453508],
#        [213.74918729],
#        [342.16271609],
#        [397.00565577],
#        [452.33090311],
#        [479.93496954],
#        [507.08185434],
#        [494.60455298],
#        [211.98655114],
#        [342.98635423],
#        [398.57970625],
#        [453.36467355],
#        [480.65880537],
#        [507.50572175],
#        [494.7386989 ],
#        [210.30488446],
#        [343.71608555],
#        [399.96669173],
#        [454.25166488],
#        [481.28419578],
#        [507.90245116],
#        [494.90812421],
#        [209.02015775],
#        [344.32893634],
#        [401.10990316],
#        [454.97559428],
#        [481.79803967],
#        [508.21566105],
#        [495.0338012 ],
#        [207.99658746],
#        [344.80642468],
#        [402.00461477],
#        [455.55138767],
#        [482.20543712],
#        [508.46523702],
#        [495.12663186],
#        [207.17400208],
#        [345.18289417],
#        [402.72105783],
#        [456.00941151],
#        [482.52842605],
#        [508.66390586],
#        [495.20271182],
#        [206.51918098],
#        [345.48389196],
#        [403.38074505],
#        [456.40207022],
#        [482.80892998],
#        [508.84301662],
#        [495.2638191 ],
#        [205.99693835],
#        [345.73145598],
#        [403.91302407],
#        [456.72318757],
#        [483.04039836],
#        [508.99508297],
#        [495.31145096],
#        [205.55748999],
#        [345.93464002],
#        [404.35284674],
#        [456.98881239],
#        [483.23176801],
#        [509.12417561],
#        [495.35243869],
#        [205.19377068],
#        [346.10338688],
#        [404.71836746],
#        [457.20895767],
#        [483.39005738],
#        [509.23099637],
#        [495.38827956],
#        [204.89214122],
#        [346.2438494 ],
#        [405.02189189],
#        [457.39209235],
#        [483.52186382],
#        [509.31994349],
#        [495.42047083],
#        [204.6405533 ],
#        [346.36161894],
#        [405.27553856],
#        [457.54528165],
#        [483.63210022],
#        [509.39457297],
#        [495.44798315],
#        [204.43056136],
#        [346.45992398],
#        [405.4873085 ],
#        [457.67311096],
#        [483.72408867],
#        [509.45684999],
#        [495.47109723],
#        [204.25678462],
#        [346.54154852],
#        [405.66291004],
#        [457.7791363 ],
#        [483.80040258],
#        [509.50845897],
#        [495.49000025],
#        [204.12792593],
#        [346.60363838],
#        [405.79808533],
#        [457.86101818],
#        [483.85917038],
#        [509.54748154],
#        [495.50314814],
#        [204.02611166],
#        [346.65129364],
#        [405.90251982],
#        [457.92460531],
#        [483.90488386],
#        [509.57798839],
#        [495.51353544],
#        [203.94689679],
#        [346.6884914 ],
#        [405.98435491],
#        [457.97406197],
#        [483.9403972 ],
#        [509.60180432],
#        [495.52172363],
#        [203.88550878],
#        [346.7174542 ],
#        [406.0476613 ],
#        [458.01242948],
#        [483.96814346],
#        [509.62019265],
#        [495.52789986],
#        [203.83766636],
#        [346.73977286],
#        [406.09697759],
#        [458.04228127],
#        [483.98933917],
#        [509.63451028],
#        [495.53285956],
#        [203.80046859],
#        [346.75736576],
#        [406.13539189],
#        [458.06553572],
#        [484.00613666],
#        [509.645693  ],
#        [495.53669631],
#        [203.77162278],
#        [346.77098155],
#        [406.1651969 ],
#        [458.08364332],
#        [484.01914418],
#        [509.65434909],
#        [495.53978443],
#        [203.74902338],
#        [346.78167298],
#        [406.18849814],
#        [458.09777379],
#        [484.02929753],
#        [509.6610868 ],
#        [495.54203033],
#        [203.73147726],
#        [346.78993136],
#        [406.20660573],
#        [458.10872257],
#        [484.03720498],
#        [509.66642082],
#        [495.54390192],
#        [203.71781468],
#        [346.79631814],
#        [406.22068942],
#        [458.11723828],
#        [484.04328763],
#        [509.67049152],
#        [495.54525882],
#        [203.70726362],
#        [346.80134803],
#        [406.23154461],
#        [458.12388241],
#        [484.04806018],
#        [509.67372   ],
#        [495.54633498],
#        [203.69914562],
#        [346.80516139],
#        [406.24006033],
#        [458.12902927],
#        [484.05180335],
#        [509.67615306],
#        [495.54713041],
#        [203.69268864],
#        [346.80803895],
#        [406.24661088],
#        [458.1329596 ],
#        [484.05451715],
#        [509.67797786],
#        [495.54778546],
#        [203.68765876],
#        [346.81047201],
#        [406.25166416],
#        [458.13604772],
#        [484.05676305],
#        [509.67952192],
#        [495.54830015],
#        [203.6838454 ],
#        [346.81239039],
#        [406.25578165],
#        [458.13857436],
#        [484.05854106],
#        [509.68064487],
#        [495.54867446],
#        [203.68089765],
#        [346.81374729],
#        [406.25886977],
#        [458.14044595],
#        [484.05994475],
#        [509.68158066],
#        [495.5489552 ],
#        [203.67858157],
#        [346.81482345],
#        [406.26111567],
#        [458.14184964],
#        [484.06088054],
#        [509.68223572],
#        [495.54928273],
#        [203.6766398 ],
#        [346.81571245],
#        [406.26317441],
#        [458.14297259],
#        [484.06181633],
#        [509.68279719],
#        [495.54946989],
#        [203.67516592],
#        [346.81636751],
#        [406.26471847],
#        [458.14390838],
#        [484.06247139],
#        [509.68331188],
#        [495.54956347],
#        [203.67415994],
#        [346.8168588 ],
#        [406.26579463],
#        [458.14456344],
#        [484.06298608],
#        [509.68359262],
#        [495.54975063],
#        [203.67327094],
#        [346.81727991],
#        [406.26663685],
#        [458.14512491],
#        [484.0633136 ],
#        [509.68382657],
#        [495.54979742],
#        [203.67266268],
#        [346.81753725],
#        [406.2672919 ],
#        [458.14549923],
#        [484.06359434],
#        [509.6841073 ],
#        [495.549891  ],
#        [203.67214799],
#        [346.81781799],
#        [406.26785338],
#        [458.14577997],
#        [484.06382829],
#        [509.68420088],
#        [495.54998457],
#        [203.67179707],
#        [346.81786478],
#        [406.26813412],
#        [458.14596713],
#        [484.06387508],
#        [509.68429446],
#        [495.55003136],
#        [203.67137596],
#        [346.81814551],
#        [406.26850843],
#        [458.14620107],
#        [484.06406224],
#        [509.68438804],
#        [495.55003136],
#        [203.6712122 ],
#        [346.8181923 ],
#        [406.2686488 ],
#        [458.14624786],
#        [484.06415582],
#        [509.68443483],
#        [495.55003136],
#        [203.67100164],
#        [346.81833267],
#        [406.26892954],
#        [458.14648181],
#        [484.06429619],
#        [509.68448162],
#        [495.55007815],
#        [203.67090806],
#        [346.81830928],
#        [406.26906991],
#        [458.14662218],
#        [484.06438977],
#        [509.6845752 ],
#        [495.55017173],
#        [203.6707443 ],
#        [346.81847304],
#        [406.26925707],
#        [458.14671576]])

# %%
test.plot(figsize = (16,5), legend=True)
lstm_predictions.plot(legend = True);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-68c6cbde862e> in <module>()
# ----> 1 test.plot(figsize = (16,5), legend=True)
#       2 lstm_predictions.plot(legend = True);
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
list = lstm_predictions[0]

# %%
list
# Out:
# array([207.44138151])

# %%
# Out:
#                                                               presence
# date
# 2021-08-21 00:00:00                                                 98
# 2021-08-22 00:00:00                                                117
# 2021-08-23 00:00:00                                                127
# 2021-08-24 00:00:00                                                118
# 2021-08-25 00:00:00                                                116
# ...                                                                ...
# 2022-08-13 00:00:00                                                104
# 2022-08-14 00:00:00                                                136
# 2022-08-15 00:00:00                                                134
# ARIMA_Predictions    2021-08-21    104.527526
# 2021-08-22    124.997...
# LSTM_Predictions     [[73.81206423044205], [93.69040250778198], [10...
#
# [362 rows x 1 columns]
