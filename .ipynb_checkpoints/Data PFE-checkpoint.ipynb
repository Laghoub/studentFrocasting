# %%
# !git clone https://github.com/Laghoub/studentFrocasting.git
# Out:
# Cloning into 'studentFrocasting'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 41 (delta 5), reused 41 (delta 5), pack-reused 0
# Unpacking objects: 100% (41/41), done.

# %% [markdown]
# ## Installation des bibliotheques necessaires

# %% [markdown]
# ## Dans un prmier temps nous installons les modules necessaires

# %% [markdown]
# **NumPy** (pour Numerical Python) est un outil parfait pour le calcul scientifique et la réalisation d’opérations de base et avancées avec des tableaux.
#
# **Pandas** est une bibliothèque créée pour aider les développeurs à travailler intuitivement avec des données « étiquetées » et « relationnelles ». Elle est basée sur deux structures de données principales : « Série » (unidimensionnelle, comme une liste Python) et « Dataframe » (bidimensionnelle, comme un tableau à plusieurs colonnes).
#
# **Matplotlib** est une bibliothèque scientifique de données standard qui aide à générer des visualisations de données telles que des diagrammes et des graphiques bidimensionnels (histogrammes, diagrammes de dispersion, graphiques de coordonnées non cartésiennes).
#
# **Seaborn** est basé sur Matplotlib et sert d’outil de Machine Learning Python utile pour la visualisation de modèles statistiques – cartes thermiques et autres types de visualisations qui résument les données et dépeignent les distributions globales.
#
# **TensorFlow** est un framework Python populaire pour le Machine Learning et le Deep Learning, qui a été développé à Google Brain. C’est le meilleur outil pour des tâches comme l’identification d’objets, la reconnaissance vocale et bien d’autres. Il permet de travailler avec des réseaux neuronaux artificiels qui doivent gérer plusieurs ensembles de données.

# %%
from random import choices
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix 
import lightgbm as lgb

# %% [markdown]
# ## **Génération de la table météo**

# %%
Type = ['Ensoleillé' , 'Nuageux' , 'Pluvieux']
weightsSep = [0.75,0.25,0]
weightsOct = [0.25,0.75,0]
weightsNov = [0.2,0.8,0.2]
weightshiv = [0,0.3,0.7]
weightsmars = [0.1,0.2,0.7]
weightsAvr = [0.25,0.4,0.35]
weightsmai = [0.5,0.4,0.1]
weightsete = [0.95,0.05,0]

# %%
ListDate = []

# %%
import datetime
for i in range(1080):
    date = datetime.datetime(2019,9,1,12,4,5) + datetime.timedelta(days=i)
    dateStr = date.strftime("%d-%m-%Y")
    ListDate.append(dateStr)    

ListDate

# %%
for j in range(30):
    choix = choices(Type,weightsSep)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsOct)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsNov)[0]
    meteo.append(choix)

# %%
for j in range(90):
    choix = choices(Type,weightshiv)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsmars)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsAvr)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsmai)[0]
    meteo.append(choix)

# %%
for j in range(90):
    choix = choices(Type,weightsete)[0]
    meteo.append(choix)

# %%
len(meteo)

# %%
len(ListDate)

# %%
datameteo = {
  "date": ListDate,
  "meteo": meteo
}
df_meteo = pd.DataFrame(datameteo)

# %%
df

# %%
df.to_excel("datameteo.xlsx")

# %%
dataevent = pd.read_excel("/content/studentFrocasting/event.xlsx")
dataevent
# Out:
#       Unnamed: 0        date    Event
# 0              0  01-09-2019   Normal
# 1              1  02-09-2019   Normal
# 2              2  03-09-2019   Normal
# 3              3  04-09-2019   Normal
# 4              4  05-09-2019   Normal
# ...          ...         ...      ...
# 1075        1075  11-08-2022   Normal
# 1076        1076  12-08-2022  Weekend
# 1077        1077  13-08-2022   Normal
# 1078        1078  14-08-2022   Normal
# 1079        1079  15-08-2022   Normal
#
# [1080 rows x 3 columns]

# %%
donnees = pd.read_excel("/content/studentFrocasting/menu.xlsx")
donnees
# Out:
#      idRestaurant        date  Type       Plat
# 0          Esi016  01-09-2019  midi  Lentilles
# 1          Esi016  02-09-2019  midi     Loubia
# 2          Esi016  03-09-2019  midi        Riz
# 3          Esi016  04-09-2019  midi  Spaghetti
# 4          Esi016  05-09-2019  midi   Couscous
# ...           ...         ...   ...        ...
# 3235  Bouraoui016  11-08-2022  soir   Couscous
# 3236  Bouraoui016  12-08-2022  soir  Lentilles
# 3237  Bouraoui016  13-08-2022  soir      Kebab
# 3238  Bouraoui016  14-08-2022  soir     Frites
# 3239  Bouraoui016  15-08-2022  soir  Spaghetti
#
# [3240 rows x 4 columns]

# %%
salaire = [random.randrange(18000,25000), random.randrange(25000,40000) , random.randrange(40000,50000), random.randrange(50000,60000),
           random.randrange(60000,80000),random.randrange(80000,100000), random.randrange(100000,120000), 
          random.randrange(120000,150000), random.randrange(150000,200000)]
poids = [0.20,0.15,0.2,0.15,0.1,0.06,0.06,0.05,0.03]
moyDesRev = []

# %% [markdown]
# # génération de la colonne moyenne des revenus

# %%
for i in range (200):
    moyDesRev.append(choices(salaire,poids)[0])

# %%
moyDesRev

# %% [markdown]
# # La colonne hebergement

# %%
hebergTypes = ['interne' , 'externe']
poidsHeb = [0.3 , 0.7]
listHeb = []

# %%
for i in range(200):
    listHeb.append(choices(hebergTypes,poidsHeb)[0])

# %%
listHeb
# Out:
# ['interne',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'interne',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'interne',
#  'interne',
#  'interne',
#  'interne',
#  'externe']

# %%
population = {
  "Heberg": listHeb,
  "Rev_par": moyDesRev
}
pop = pd.DataFrame(population)

# %%
pop
# Out:
#       Heberg  Rev_par
# 0    interne    56879
# 1    externe    19184
# 2    externe    56879
# 3    externe    19184
# 4    interne   139936
# ..       ...      ...
# 195  interne    25251
# 196  interne    19184
# 197  interne    56879
# 198  interne    56879
# 199  externe    46901
#
# [200 rows x 2 columns]

# %%
pop.to_excel("etudiants.xlsx")

# %% [markdown]
# # La table population

# %%
df_population = pd.read_excel("etudiants.xlsx")
df_population
# Out:
#     idEtudiant   Heberg  Rev_par Bourse idRestaurant
# 0      17/0001  interne    56879    Oui       Esi016
# 1      17/0002  externe    19184    Oui       Esi016
# 2      17/0003  externe    56879    Oui       Esi016
# 3      17/0004  externe    19184    Oui       Esi016
# 4      17/0005  interne   139936    Non       Esi016
# ..         ...      ...      ...    ...          ...
# 195    17/0196  interne    25251    Oui       Esi016
# 196    17/0197  interne    19184    Oui       Esi016
# 197    17/0198  interne    56879    Oui       Esi016
# 198    17/0199  interne    56879    Oui       Esi016
# 199    17/0200  externe    46901    Oui       Esi016
#
# [200 rows x 5 columns]

# %%
df_event= pd.read_excel("event.xlsx")
df_event
# Out:
#       Unnamed: 0        date    Event
# 0              0  01-09-2019   Normal
# 1              1  02-09-2019   Normal
# 2              2  03-09-2019   Normal
# 3              3  04-09-2019   Normal
# 4              4  05-09-2019   Normal
# ...          ...         ...      ...
# 1075        1075  11-08-2022   Normal
# 1076        1076  12-08-2022  Weekend
# 1077        1077  13-08-2022   Normal
# 1078        1078  14-08-2022   Normal
# 1079        1079  15-08-2022   Normal
#
# [1080 rows x 3 columns]

# %%
df_meteo = pd.read_excel("meteo.xlsx")
df_meteo
# Out:
#       Unnamed: 0        date       meteo
# 0              0  01-09-2019  Ensoleillé
# 1              1  02-09-2019  Ensoleillé
# 2              2  03-09-2019  Ensoleillé
# 3              3  04-09-2019  Ensoleillé
# 4              4  05-09-2019  Ensoleillé
# ...          ...         ...         ...
# 1075        1075  11-08-2022  Ensoleillé
# 1076        1076  12-08-2022  Ensoleillé
# 1077        1077  13-08-2022  Ensoleillé
# 1078        1078  14-08-2022  Ensoleillé
# 1079        1079  15-08-2022  Ensoleillé
#
# [1080 rows x 3 columns]

# %%
df_menu=pd.read_excel("menu.xlsx")

# %%
df_menu_Esi=df_menu.loc[df_menu['idRestaurant'] == "Esi016"]
df_menu_Esi
# Out:
#      idRestaurant        date  Type       Plat
# 0          Esi016  01-09-2019  midi  Lentilles
# 1          Esi016  02-09-2019  midi     Loubia
# 2          Esi016  03-09-2019  midi        Riz
# 3          Esi016  04-09-2019  midi  Spaghetti
# 4          Esi016  05-09-2019  midi   Couscous
# ...           ...         ...   ...        ...
# 1075       Esi016  11-08-2022  midi   Couscous
# 1076       Esi016  12-08-2022  midi    Weekend
# 1077       Esi016  13-08-2022  midi    Weekend
# 1078       Esi016  14-08-2022  midi  Lentilles
# 1079       Esi016  15-08-2022  midi     Loubia
#
# [1080 rows x 4 columns]

# %%
result = pd.merge(df_menu_Esi,df_meteo, on="date")
result2 = pd.merge(result,df_event, on="date")

# %%
result2
# Out:
#      idRestaurant        date  Type       Plat  Unnamed: 0_x       meteo  \
# 0          Esi016  01-09-2019  midi  Lentilles             0  Ensoleillé
# 1          Esi016  02-09-2019  midi     Loubia             1  Ensoleillé
# 2          Esi016  03-09-2019  midi        Riz             2  Ensoleillé
# 3          Esi016  04-09-2019  midi  Spaghetti             3  Ensoleillé
# 4          Esi016  05-09-2019  midi   Couscous             4  Ensoleillé
# ...           ...         ...   ...        ...           ...         ...
# 1075       Esi016  11-08-2022  midi   Couscous          1075  Ensoleillé
# 1076       Esi016  12-08-2022  midi    Weekend          1076  Ensoleillé
# 1077       Esi016  13-08-2022  midi    Weekend          1077  Ensoleillé
# 1078       Esi016  14-08-2022  midi  Lentilles          1078  Ensoleillé
# 1079       Esi016  15-08-2022  midi     Loubia          1079  Ensoleillé
#
#       Unnamed: 0_y    Event
# 0                0   Normal
# 1                1   Normal
# 2                2   Normal
# 3                3   Normal
# 4                4   Normal
# ...            ...      ...
# 1075          1075   Normal
# 1076          1076  Weekend
# 1077          1077   Normal
# 1078          1078   Normal
# 1079          1079   Normal
#
# [1080 rows x 8 columns]

# %%
resultf = result2.drop(columns=["Unnamed: 0_x","Unnamed: 0_y"], axis=1)

# %%
resultf
# Out:
#      idRestaurant        date  Type       Plat       meteo    Event
# 0          Esi016  01-09-2019  midi  Lentilles  Ensoleillé   Normal
# 1          Esi016  02-09-2019  midi     Loubia  Ensoleillé   Normal
# 2          Esi016  03-09-2019  midi        Riz  Ensoleillé   Normal
# 3          Esi016  04-09-2019  midi  Spaghetti  Ensoleillé   Normal
# 4          Esi016  05-09-2019  midi   Couscous  Ensoleillé   Normal
# ...           ...         ...   ...        ...         ...      ...
# 1075       Esi016  11-08-2022  midi   Couscous  Ensoleillé   Normal
# 1076       Esi016  12-08-2022  midi    Weekend  Ensoleillé  Weekend
# 1077       Esi016  13-08-2022  midi    Weekend  Ensoleillé   Normal
# 1078       Esi016  14-08-2022  midi  Lentilles  Ensoleillé   Normal
# 1079       Esi016  15-08-2022  midi     Loubia  Ensoleillé   Normal
#
# [1080 rows x 6 columns]

# %%
df_pop = pd.read_excel("etudiants.xlsx")
df_pop
# Out:
#     idEtudiant   Heberg  Rev_par Bourse idRestaurant
# 0      17/0001  interne    56879    Oui       Esi016
# 1      17/0002  externe    19184    Oui       Esi016
# 2      17/0003  externe    56879    Oui       Esi016
# 3      17/0004  externe    19184    Oui       Esi016
# 4      17/0005  interne   139936    Non       Esi016
# ..         ...      ...      ...    ...          ...
# 195    17/0196  interne    25251    Oui       Esi016
# 196    17/0197  interne    19184    Oui       Esi016
# 197    17/0198  interne    56879    Oui       Esi016
# 198    17/0199  interne    56879    Oui       Esi016
# 199    17/0200  externe    46901    Oui       Esi016
#
# [200 rows x 5 columns]

# %%
resultMerge = pd.merge(resultf,df_pop, on="idRestaurant")
resultMerge
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse
# 0         17/0001  interne    56879    Oui
# 1         17/0002  externe    19184    Oui
# 2         17/0003  externe    56879    Oui
# 3         17/0004  externe    19184    Oui
# 4         17/0005  interne   139936    Non
# ...           ...      ...      ...    ...
# 215995    17/0196  interne    25251    Oui
# 215996    17/0197  interne    19184    Oui
# 215997    17/0198  interne    56879    Oui
# 215998    17/0199  interne    56879    Oui
# 215999    17/0200  externe    46901    Oui
#
# [216000 rows x 10 columns]

# %%
resultMerge.to_csv("dataset.csv")

# %%
table = pd.read_csv("dataset.csv")
table
# Out:
#         Unnamed: 0 idRestaurant        date  Type       Plat       meteo  \
# 0                0       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 1                1       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 2                2       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 3                3       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 4                4       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# ...            ...          ...         ...   ...        ...         ...
# 215995      215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215996      215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215997      215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215998      215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215999      215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé
#
#          Event idEtudiant   Heberg  Rev_par Bourse
# 0       Normal    17/0001  interne    56879    Oui
# 1       Normal    17/0002  externe    19184    Oui
# 2       Normal    17/0003  externe    56879    Oui
# 3       Normal    17/0004  externe    19184    Oui
# 4       Normal    17/0005  interne   139936    Non
# ...        ...        ...      ...      ...    ...
# 215995  Normal    17/0196  interne    25251    Oui
# 215996  Normal    17/0197  interne    19184    Oui
# 215997  Normal    17/0198  interne    56879    Oui
# 215998  Normal    17/0199  interne    56879    Oui
# 215999  Normal    17/0200  externe    46901    Oui
#
# [216000 rows x 11 columns]

# %%
table2 = table.drop(columns=['Unnamed: 0'], axis=1)
table2
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse
# 0         17/0001  interne    56879    Oui
# 1         17/0002  externe    19184    Oui
# 2         17/0003  externe    56879    Oui
# 3         17/0004  externe    19184    Oui
# 4         17/0005  interne   139936    Non
# ...           ...      ...      ...    ...
# 215995    17/0196  interne    25251    Oui
# 215996    17/0197  interne    19184    Oui
# 215997    17/0198  interne    56879    Oui
# 215998    17/0199  interne    56879    Oui
# 215999    17/0200  externe    46901    Oui
#
# [216000 rows x 10 columns]

# %% [markdown]
# # Probabilité selon le plat

# %%
def probPlat(plat):
    if (plat=="Lentilles"):
        return 0.1
    if (plat=="Loubia"):
        return 0.12
    if (plat=="Riz"):
        return 0.4*0.2
    if (plat=="Spaghetti"):
        return 0.3*0.2
    if (plat=="Couscous"):
        return 0.9*0.2
    else: return 0

# %%
probPlat("Couscous")
# Out:
# 0.18000000000000002

# %% [markdown]
# # Probabilité selon la météo

# %%
def probMeteo(meteo):
    if (meteo=="Ensoleillé"):
        return 0.02
    if (meteo=="Nuageux"):
        return 0.06
    if (meteo=="Mauvais"):
        return 0.09

# %% [markdown]
# # Probabilité selon la bourse

# %%
def probBourse(bourse):
    if(bourse=="Oui"):
        return 0.7*0.1
    if(bourse=="Non"):
        return 0.6*0.1

# %% [markdown]
# # Probabilité selon l'hébergement

# %%
def probHeberg(heberg):
    if(heberg=="externe"):
        return 0.25*0.8
    if(heberg=="interne"):
        return 0.25*0.5

# %% [markdown]
# # probabilité selon les revenues des parents

# %%
def probRevenues(revenu):
    if(revenu<50000):
        return 0.9*0.35
    if(revenu>50000 and revenu<100000):
        return 0.6*0.35
    if (revenu>100000 and revenu<150000):
        return 0.3*0.35
    if (revenu>150000):
        return 0.05*0.35

# %% [markdown]
# # probabilité selon les evenements

# %%
def probEvent(event):
    if(event=="Normal"):
        return 1
    return 0

# %%
probEvent("Normal")
# Out:
# 1

# %%
table3 = table2.assign(presence=0.001)

# %%
table3
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse  presence
# 0         17/0001  interne    56879    Oui     0.001
# 1         17/0002  externe    19184    Oui     0.001
# 2         17/0003  externe    56879    Oui     0.001
# 3         17/0004  externe    19184    Oui     0.001
# 4         17/0005  interne   139936    Non     0.001
# ...           ...      ...      ...    ...       ...
# 215995    17/0196  interne    25251    Oui     0.001
# 215996    17/0197  interne    19184    Oui     0.001
# 215997    17/0198  interne    56879    Oui     0.001
# 215998    17/0199  interne    56879    Oui     0.001
# 215999    17/0200  externe    46901    Oui     0.001
#
# [216000 rows x 11 columns]

# %%
for i in range(216000):
    table3["presence"][i] =(probPlat(table3["Plat"][i])+probMeteo(table3["meteo"][i])+probBourse(table3["Bourse"][i])+probHeberg(table3["Heberg"][i])+probRevenues(table3["Rev_par"][i]))*probEvent(table3["Event"][i])
# Out:
# <ipython-input-92-c168420c2611>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table3["presence"][i] =(probPlat(table3["Plat"][i])+probMeteo(table3["meteo"][i])+probBourse(table3["Bourse"][i])+probHeberg(table3["Heberg"][i])+probRevenues(table3["Rev_par"][i]))*probEvent(table3["Event"][i])

# %%
table3
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse  presence
# 0         17/0001  interne    56879    Oui     0.525
# 1         17/0002  externe    19184    Oui     0.705
# 2         17/0003  externe    56879    Oui     0.600
# 3         17/0004  externe    19184    Oui     0.705
# 4         17/0005  interne   139936    Non     0.410
# ...           ...      ...      ...    ...       ...
# 215995    17/0196  interne    25251    Oui     0.650
# 215996    17/0197  interne    19184    Oui     0.650
# 215997    17/0198  interne    56879    Oui     0.545
# 215998    17/0199  interne    56879    Oui     0.545
# 215999    17/0200  externe    46901    Oui     0.725
#
# [216000 rows x 11 columns]

# %%
table3.to_csv("dataset0.csv")

# %%
table3 =pd.read_csv("dataset0.csv")

# %%
table3.rename(columns={'presence': 'presenceP'}, inplace=True)

# %%
table3 = table3.assign(presence=0)
table3
# Out:
#         Unnamed: 0 idRestaurant        date  Type       Plat       meteo  \
# 0                0       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 1                1       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 2                2       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 3                3       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 4                4       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# ...            ...          ...         ...   ...        ...         ...
# 215995      215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215996      215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215997      215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215998      215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215999      215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé
#
#          Event idEtudiant   Heberg  Rev_par Bourse  presenceP  presence
# 0       Normal    17/0001  interne    56879    Oui      0.525         0
# 1       Normal    17/0002  externe    19184    Oui      0.705         0
# 2       Normal    17/0003  externe    56879    Oui      0.600         0
# 3       Normal    17/0004  externe    19184    Oui      0.705         0
# 4       Normal    17/0005  interne   139936    Non      0.410         0
# ...        ...        ...      ...      ...    ...        ...       ...
# 215995  Normal    17/0196  interne    25251    Oui      0.650         0
# 215996  Normal    17/0197  interne    19184    Oui      0.650         0
# 215997  Normal    17/0198  interne    56879    Oui      0.545         0
# 215998  Normal    17/0199  interne    56879    Oui      0.545         0
# 215999  Normal    17/0200  externe    46901    Oui      0.725         0
#
# [216000 rows x 13 columns]

# %%
def decide(presP):
    Type = [0,1]
    weight = [1-presP,presP]
    return choices(Type,weight)[0]

# %%
decide(0.2)
# Out:
# 0

# %%
for i in range(216000):
    table3["presence"][i] = decide(table3["presenceP"][i])
# Out:
# <ipython-input-18-b2e2581f3c36>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table3["presence"][i] = decide(table3["presenceP"][i])

# %%
table3
# Out:
#         Unnamed: 0 idRestaurant        date  Type       Plat       meteo  \
# 0                0       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 1                1       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 2                2       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 3                3       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 4                4       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# ...            ...          ...         ...   ...        ...         ...
# 215995      215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215996      215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215997      215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215998      215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215999      215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé
#
#          Event idEtudiant   Heberg  Rev_par Bourse  presenceP  presence
# 0       Normal    17/0001  interne    56879    Oui      0.525         0
# 1       Normal    17/0002  externe    19184    Oui      0.705         1
# 2       Normal    17/0003  externe    56879    Oui      0.600         1
# 3       Normal    17/0004  externe    19184    Oui      0.705         1
# 4       Normal    17/0005  interne   139936    Non      0.410         0
# ...        ...        ...      ...      ...    ...        ...       ...
# 215995  Normal    17/0196  interne    25251    Oui      0.650         1
# 215996  Normal    17/0197  interne    19184    Oui      0.650         1
# 215997  Normal    17/0198  interne    56879    Oui      0.545         0
# 215998  Normal    17/0199  interne    56879    Oui      0.545         0
# 215999  Normal    17/0200  externe    46901    Oui      0.725         1
#
# [216000 rows x 13 columns]

# %%
table3.to_csv("tablePredection.csv")

# %%
f,ax = plt.subplots(1,1,figsize=(20,8))
plt1 = table3.groupby(['date'], as_index=False).agg({'presence': np.sum})
plt1=plt1.set_index('date')
plt1.plot(color='salmon', kind='area', ax=ax)
plt.ylabel("Total des présents")
plt.title("Répartitions des présents par date")
# Out:
# Text(0.5, 1.0, 'Répartitions des présents par date')

# %%
table4=table3.groupby(['date'],as_index=False).sum()

# %%
table4 = table4[['date','presence']].sort_values(by=['date'], 
ascending=True)

# %%
table4
# Out:
#             date  presence
# 0     01-01-2020         0
# 1     01-01-2021         0
# 2     01-01-2022         0
# 3     01-02-2020       105
# 4     01-02-2021       176
# ...          ...       ...
# 1075  31-10-2020        82
# 1076  31-10-2021       153
# 1077  31-12-2019       153
# 1078  31-12-2020       186
# 1079  31-12-2021         0
#
# [1080 rows x 2 columns]

# %%
pres = pd.read_excel("presdate.xlsx")
pres
# Out:
#            date  presence
# 0    2019-09-01       153
# 1    2019-09-02       153
# 2    2019-09-03       105
# 3    2019-09-04        82
# 4    2019-09-05       176
# ...         ...       ...
# 1075 2022-08-11       176
# 1076 2022-08-12         0
# 1077 2022-08-13        82
# 1078 2022-08-14       153
# 1079 2022-08-15       153
#
# [1080 rows x 2 columns]

# %%
f,ax = plt.subplots(1,1,figsize=(20,8))
plt1=pres.set_index('date')
plt1.plot(color='salmon', kind='area', ax=ax)
plt.ylabel("Total des présents")
plt.title("Répartitions des présents par date")
# Out:
# Text(0.5, 1.0, 'Répartitions des présents par date')

# %%
plt.figure(figsize=(15,7))
plt.plot(pres['date'][0:365], pres['presence'][0:365])
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")
plt.show()

# %%
for i in range(1080):
    pres['date'][i] = str(pres['date'][i])
# Out:
# <ipython-input-159-885ff2fb9179>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pres['date'][i] = str(pres['date'][i])

# %%
presn = pd.read_excel("datasetPFE.xlsx")
presn
# Out:
#             date  presence
# 0     01-09-2019       153
# 1     02-09-2019       153
# 2     03-09-2019       105
# 3     04-09-2019        82
# 4     05-09-2019       176
# ...          ...       ...
# 1075  11-08-2022       176
# 1076  12-08-2022         0
# 1077  13-08-2022        82
# 1078  14-08-2022       153
# 1079  15-08-2022       153
#
# [1080 rows x 2 columns]

# %%
resultfinal = pd.merge(resultf,presn, on="date")
resultfinal
# Out:
#      idRestaurant        date  Type       Plat       meteo    Event  presence
# 0          Esi016  01-09-2019  midi  Lentilles  Ensoleillé   Normal       153
# 1          Esi016  02-09-2019  midi     Loubia  Ensoleillé   Normal       153
# 2          Esi016  03-09-2019  midi        Riz  Ensoleillé   Normal       105
# 3          Esi016  04-09-2019  midi  Spaghetti  Ensoleillé   Normal        82
# 4          Esi016  05-09-2019  midi   Couscous  Ensoleillé   Normal       176
# ...           ...         ...   ...        ...         ...      ...       ...
# 1075       Esi016  11-08-2022  midi   Couscous  Ensoleillé   Normal       176
# 1076       Esi016  12-08-2022  midi    Weekend  Ensoleillé  Weekend         0
# 1077       Esi016  13-08-2022  midi    Weekend  Ensoleillé   Normal        82
# 1078       Esi016  14-08-2022  midi  Lentilles  Ensoleillé   Normal       153
# 1079       Esi016  15-08-2022  midi     Loubia  Ensoleillé   Normal       153
#
# [1080 rows x 7 columns]

# %%
table3["Plat"].replace(["Lentilles","Loubia","Riz","Spaghetti","Couscous","Weekend"],[0,1,2,3,4,5],inplace=True)
table3["meteo"].replace(["Ensoleillé","Nuageux","Mauvais"],[0,1,2],inplace=True)
table3["Event"].replace(["Normal","Weekend","Jour férié","Ramadan"],[0,1,2,3],inplace=True)
table3["Heberg"].replace(["interne","externe"],[0,1],inplace=True)
table3["Bourse"].replace(["Oui","Non"],[0,1],inplace=True)

# %%
fig, axes = plt.subplots(figsize= (10,8))
sns.heatmap(table3.corr(), annot=True, cmap='Oranges')
plt.xticks(rotation=30, ha='right')
plt.title("Matrice de corrélation")
plt.show()

# %%
table3
# Out:
#         Unnamed: 0 idRestaurant        date  Type  Plat  meteo  Event  \
# 0                0       Esi016  01-09-2019  midi     0      0      0
# 1                1       Esi016  01-09-2019  midi     0      0      0
# 2                2       Esi016  01-09-2019  midi     0      0      0
# 3                3       Esi016  01-09-2019  midi     0      0      0
# 4                4       Esi016  01-09-2019  midi     0      0      0
# ...            ...          ...         ...   ...   ...    ...    ...
# 215995      215995       Esi016  15-08-2022  midi     1      0      0
# 215996      215996       Esi016  15-08-2022  midi     1      0      0
# 215997      215997       Esi016  15-08-2022  midi     1      0      0
# 215998      215998       Esi016  15-08-2022  midi     1      0      0
# 215999      215999       Esi016  15-08-2022  midi     1      0      0
#
#        idEtudiant  Heberg  Rev_par  Bourse  presenceP  presence
# 0         17/0001       0    56879       0      0.525         0
# 1         17/0002       1    19184       0      0.705         1
# 2         17/0003       1    56879       0      0.600         1
# 3         17/0004       1    19184       0      0.705         1
# 4         17/0005       0   139936       1      0.410         0
# ...           ...     ...      ...     ...        ...       ...
# 215995    17/0196       0    25251       0      0.650         1
# 215996    17/0197       0    19184       0      0.650         1
# 215997    17/0198       0    56879       0      0.545         0
# 215998    17/0199       0    56879       0      0.545         0
# 215999    17/0200       1    46901       0      0.725         1
#
# [216000 rows x 13 columns]

# %% [markdown]
# # Construction de jeu de données

# %%
training_data = table3.sample(frac=2/3, random_state=0)
testing_data = table3.drop(training_data.index)

# %%
training_data.size
# Out:
# 1728000

# %%
testing_data.size
# Out:
# 864000

# %%
training_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-aa4368bc1598> in <module>
# ----> 1 training_data
#
# NameError: name 'training_data' is not defined

# %%
x=table3.drop(["idRestaurant","Type","idEtudiant","presenceP","presence","Unnamed: 0","meteo","Bourse"] , axis=1)   
y=table3["presence"]

# %%
x
# Out:
#               date  Plat  Event  Heberg  Rev_par
# 0       01-09-2019     0      0       0    56879
# 1       01-09-2019     0      0       1    19184
# 2       01-09-2019     0      0       1    56879
# 3       01-09-2019     0      0       1    19184
# 4       01-09-2019     0      0       0   139936
# ...            ...   ...    ...     ...      ...
# 215995  15-08-2022     1      0       0    25251
# 215996  15-08-2022     1      0       0    19184
# 215997  15-08-2022     1      0       0    56879
# 215998  15-08-2022     1      0       0    56879
# 215999  15-08-2022     1      0       1    46901
#
# [216000 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=1/3,random_state=None,shuffle = False)

# %%
X_train=X_train.drop(["date"],axis=1)

# %%
X_train
# Out:
#         Plat  Event  Heberg  Rev_par
# 0          0      0       0    56879
# 1          0      0       1    19184
# 2          0      0       1    56879
# 3          0      0       1    19184
# 4          0      0       0   139936
# ...      ...    ...     ...      ...
# 143995     5      1       0    25251
# 143996     5      1       0    19184
# 143997     5      1       0    56879
# 143998     5      1       0    56879
# 143999     5      1       1    46901
#
# [144000 rows x 4 columns]

# %%
X_test.drop(["date"],axis=1)
# Out:
#         Plat  Event  Heberg  Rev_par
# 144000     5      0       0    56879
# 144001     5      0       1    19184
# 144002     5      0       1    56879
# 144003     5      0       1    19184
# 144004     5      0       0   139936
# ...      ...    ...     ...      ...
# 215995     1      0       0    25251
# 215996     1      0       0    19184
# 215997     1      0       0    56879
# 215998     1      0       0    56879
# 215999     1      0       1    46901
#
# [72000 rows x 4 columns]

# %%
 from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
print('Score du model =', model.score(X_train,y_train ))
# Out:
# Score du model = 0.4676458333333333

# %%
cm = confusion_matrix(model.predict(X_train),y_train)
print(cm)
# Out:
# [[49846  6334]
#  [17495 70325]]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(10)

# %%
model.fit(X_train,y_train )
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
print('Coeff R2 =', model.score(X_train,y_train ))
# Out:
# Coeff R2 = 1.0

# %%
cm = confusion_matrix(model.predict(X_train),y_train)
print(cm)
# Out:
# [[70883     0]
#  [    0 80317]]

# %%
tableMod = pd.read_csv("tablePredection.csv")

# %%
tableMod=tableMod.drop(["Unnamed: 0","Unnamed: 0.1"],axis=1)

# %%
tableMod
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse  presenceP  presence
# 0         17/0001  interne    56879    Oui      0.525         0
# 1         17/0002  externe    19184    Oui      0.705         1
# 2         17/0003  externe    56879    Oui      0.600         1
# 3         17/0004  externe    19184    Oui      0.705         1
# 4         17/0005  interne   139936    Non      0.410         0
# ...           ...      ...      ...    ...        ...       ...
# 215995    17/0196  interne    25251    Oui      0.650         1
# 215996    17/0197  interne    19184    Oui      0.650         1
# 215997    17/0198  interne    56879    Oui      0.545         0
# 215998    17/0199  interne    56879    Oui      0.545         0
# 215999    17/0200  externe    46901    Oui      0.725         1
#
# [216000 rows x 12 columns]

# %%
for i in range(216000):
    tableMod["presence"][i] = decide(tableMod["presenceP"][i])
# Out:
# <ipython-input-68-49da3f113eed>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableMod["presence"][i] = decide(tableMod["presenceP"][i])

# %%
tableMod
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse  presenceP  presence
# 0         17/0001  interne    56879    Oui      0.525         1
# 1         17/0002  externe    19184    Oui      0.705         0
# 2         17/0003  externe    56879    Oui      0.600         0
# 3         17/0004  externe    19184    Oui      0.705         1
# 4         17/0005  interne   139936    Non      0.410         0
# ...           ...      ...      ...    ...        ...       ...
# 215995    17/0196  interne    25251    Oui      0.650         1
# 215996    17/0197  interne    19184    Oui      0.650         1
# 215997    17/0198  interne    56879    Oui      0.545         1
# 215998    17/0199  interne    56879    Oui      0.545         0
# 215999    17/0200  externe    46901    Oui      0.725         0
#
# [216000 rows x 12 columns]

# %%
tableSum=tableMod.groupby(['date'],as_index=False).sum()
tableSum=tableSum.drop(['Rev_par','presenceP'], axis=1)

# %%
tableSum.to_excel("NbPresence.xlsx")

# %%
nbpres = pd.read_excel("NbPresence.xlsx")
nbpres
# Out:
#            date  presence
# 0    2019-09-01       118
# 1    2019-09-02       137
# 2    2019-09-03       115
# 3    2019-09-04       110
# 4    2019-09-05       139
# ...         ...       ...
# 1075 2022-08-11       126
# 1076 2022-08-12         0
# 1077 2022-08-13       104
# 1078 2022-08-14       136
# 1079 2022-08-15       134
#
# [1080 rows x 2 columns]

# %%
f,ax = plt.subplots(1,1,figsize=(20,8))
plt1=nbpres.set_index('date')
plt1.plot(color='salmon', kind='area', ax=ax)
plt.ylabel("Total des présents")
plt.title("Répartitions des présents par date")
# Out:
# Text(0.5, 1.0, 'Répartitions des présents par date')

# %% [markdown]
# # Time series

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from matplotlib.pylab import rcParams

# %%
nbpres['date'] = pd.to_datetime(nbpres['date'],infer_datetime_format=True) #convert from string to datetime
indexedDataset = nbpres.set_index(['date'])
indexedDataset.head(5)
# Out:
#             presence
# date
# 2019-09-01       118
# 2019-09-02       137
# 2019-09-03       115
# 2019-09-04       110
# 2019-09-05       139

# %%
plt.xlabel('Date')
plt.ylabel('Number of air passengers')
plt.plot(indexedDataset)

# %%
rolmean = indexedDataset.rolling(window=7).mean() #window size 12 denotes 12 months, giving rolling mean at yearly level
rolstd = indexedDataset.rolling(window=7).std()
print(rolmean,rolstd)
# Out:
#               presence
# date
# 2019-09-01         NaN
# 2019-09-02         NaN
# 2019-09-03         NaN
# 2019-09-04         NaN
# 2019-09-05         NaN
# ...                ...
# 2022-08-11   82.714286
# 2022-08-12   82.714286
# 2022-08-13   81.571429
# 2022-08-14  101.000000
# 2022-08-15  103.571429
#
# [1080 rows x 1 columns]              presence
# date
# 2019-09-01        NaN
# 2019-09-02        NaN
# 2019-09-03        NaN
# 2019-09-04        NaN
# 2019-09-05        NaN
# ...               ...
# 2022-08-11  56.747142
# 2022-08-12  56.747142
# 2022-08-13  56.136314
# 2022-08-14  45.778452
# 2022-08-15  47.243543
#
# [1080 rows x 1 columns]

# %%
#Plot rolling statistics
plt.figure(figsize=(15,7))
orig = plt.plot(indexedDataset, color='blue', label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
print('Results of Dickey Fuller Test:')
dftest = adfuller(indexedDataset['presence'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                   -5.097124
# p-value                           0.000014
# #Lags Used                       22.000000
# Number of Observations Used    1057.000000
# Critical Value (1%)              -3.436552
# Critical Value (5%)              -2.864278
# Critical Value (10%)             -2.568228
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})


# Original Series
fig, axes = plt.subplots(3, 2, sharex=False)
axes[0, 0].plot(indexedDataset.presence); axes[0, 0].set_title('Original Series')
plot_acf(indexedDataset.presence, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(indexedDataset.presence.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(indexedDataset.presence.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(indexedDataset.presence.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(indexedDataset.presence.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=False)
axes[0].plot(indexedDataset.presence); axes[0].set_title('no Differencing')
#axes[1].set(ylim=(-1,1))
plot_pacf(indexedDataset.presence.dropna(), ax=axes[1])

plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=False)
axes[0].plot(indexedDataset.presence); axes[0].set_title('no Differencing')
plot_acf(indexedDataset.presence.dropna(), ax=axes[1])

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

# 1,0,2 ARIMA Model
model = ARIMA(indexedDataset.presence, order=(1,0,2))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                 1080
# Model:                     ARMA(1, 2)   Log Likelihood               -5801.225
# Method:                       css-mle   S.D. of innovations             52.056
# Date:                Thu, 26 May 2022   AIC                          11612.451
# Time:                        19:51:55   BIC                          11637.374
# Sample:                    09-01-2019   HQIC                         11621.888
#                          - 08-15-2022
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             97.3998      6.337     15.371      0.000      84.980     109.819
# ar.L1.presence     0.9648      0.010     93.280      0.000       0.945       0.985
# ma.L1.presence    -0.9014      0.035    -25.922      0.000      -0.970      -0.833
# ma.L2.presence     0.0449      0.032      1.395      0.163      -0.018       0.108
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0365           +0.0000j            1.0365            0.0000
# MA.1            1.1786           +0.0000j            1.1786            0.0000
# MA.2           18.8972           +0.0000j           18.8972            0.0000
# -----------------------------------------------------------------------------

# %%
# 1,1,1 ARIMA Model
model = ARIMA(indexedDataset.presence, order=(1,0,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                 1080
# Model:                     ARMA(1, 1)   Log Likelihood               -5802.201
# Method:                       css-mle   S.D. of innovations             52.104
# Date:                Thu, 26 May 2022   AIC                          11612.402
# Time:                        19:57:29   BIC                          11632.341
# Sample:                    09-01-2019   HQIC                         11619.951
#                          - 08-15-2022
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             97.3929      6.310     15.435      0.000      85.025     109.760
# ar.L1.presence     0.9654      0.010     93.678      0.000       0.945       0.986
# ma.L1.presence    -0.8597      0.017    -50.064      0.000      -0.893      -0.826
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0358           +0.0000j            1.0358            0.0000
# MA.1            1.1632           +0.0000j            1.1632            0.0000
# -----------------------------------------------------------------------------

# %%
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
model_fit.predict()
# Out:
# 2019-09-01     97.392857
# 2019-09-02    102.075127
# 2019-09-03    108.445261
# 2019-09-04    109.124437
# 2019-09-05    108.846221
#                  ...
# 2022-08-11     96.660354
# 2022-08-12     99.787732
# 2022-08-13     89.154471
# 2022-08-14     91.008809
# 2022-08-15     95.986339
# Freq: D, Length: 1080, dtype: float64

# %%
train = indexedDataset.presence[:720]
test = indexedDataset.presence[720:]

# %%
test
# Out:
# date
# 2021-08-21     98
# 2021-08-22    117
# 2021-08-23    127
# 2021-08-24    118
# 2021-08-25    116
#              ...
# 2022-08-11    126
# 2022-08-12      0
# 2022-08-13    104
# 2022-08-14    136
# 2022-08-15    134
# Name: presence, Length: 360, dtype: int64

# %%
model = ARIMA(train, order=(1, 0, 1))  
fitted = model.fit(disp=-1)  
print(fitted.summary())

# Forecast
fc, se, conf = fitted.forecast(360,alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                  720
# Model:                     ARMA(1, 1)   Log Likelihood               -3868.352
# Method:                       css-mle   S.D. of innovations             52.114
# Date:                Thu, 26 May 2022   AIC                           7744.705
# Time:                        20:32:07   BIC                           7763.022
# Sample:                    09-01-2019   HQIC                          7751.776
#                          - 08-20-2021
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             96.7000      7.708     12.546      0.000      81.593     111.807
# ar.L1.presence     0.9659      0.012     77.479      0.000       0.941       0.990
# ma.L1.presence    -0.8605      0.021    -41.040      0.000      -0.902      -0.819
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0353           +0.0000j            1.0353            0.0000
# MA.1            1.1621           +0.0000j            1.1621            0.0000
# -----------------------------------------------------------------------------

# %%
model = ARIMA(train, order=(3, 0, 1))  
fitted = model.fit(disp=-1)  
print(fitted.summary())

# Forecast
fc, se, conf = fitted.forecast(360, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                  720
# Model:                     ARMA(3, 1)   Log Likelihood               -3865.841
# Method:                       css-mle   S.D. of innovations             51.930
# Date:                Thu, 26 May 2022   AIC                           7743.682
# Time:                        20:45:59   BIC                           7771.157
# Sample:                    09-01-2019   HQIC                          7754.289
#                          - 08-20-2021
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             96.7063      7.813     12.378      0.000      81.393     112.019
# ar.L1.presence     0.9029      0.045     20.132      0.000       0.815       0.991
# ar.L2.presence    -0.0234      0.050     -0.467      0.641      -0.122       0.075
# ar.L3.presence     0.0805      0.040      2.034      0.042       0.003       0.158
# ma.L1.presence    -0.8335      0.026    -31.897      0.000      -0.885      -0.782
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0362           -0.0000j            1.0362           -0.0000
# AR.2           -0.3727           -3.4415j            3.4616           -0.2672
# AR.3           -0.3727           +3.4415j            3.4616            0.2672
# MA.1            1.1997           +0.0000j            1.1997            0.0000
# -----------------------------------------------------------------------------

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    acf1 = acf(fc-test)[1]                      # ACF1
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'acf1':acf1, 
            'corr':corr, 'minmax':minmax})

forecast_accuracy(fc, test.values)
# Out:
# <ipython-input-216-901c04103e5c>:2: RuntimeWarning: divide by zero encountered in true_divide
#   mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
# <ipython-input-216-901c04103e5c>:5: RuntimeWarning: divide by zero encountered in true_divide
#   mpe = np.mean((forecast - actual)/actual)   # MPE
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:657: FutureWarning: The default number of lags is changing from 40 tomin(int(10 * np.log10(nobs)), nobs - 1) after 0.12is released. Set the number of lags to an integer to  silence this warning.
#   warnings.warn(
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(
# {'mape': inf,
#  'me': -1.5695055585589053,
#  'mae': 46.67821595130775,
#  'mpe': inf,
#  'rmse': 56.100250630935896,
#  'acf1': 0.19628792802048933,
#  'corr': 0.10209261158114882,
#  'minmax': 0.42157167488051306}

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.5-cp38-cp38-win_amd64.whl (602 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\laghoub\anaconda3\lib\site-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\laghoub\anaconda3\lib\site-packages (from pmdarima) (1.6.2)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in c:\users\laghoub\anaconda3\lib\site-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\laghoub\anaconda3\lib\site-packages (from pmdarima) (52.0.0.post20210125)
# Requirement already satisfied: urllib3 in c:\users\laghoub\anaconda3\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in c:\users\laghoub\anaconda3\lib\site-packages (from pmdarima) (0.29.23)
# Requirement already satisfied: pandas>=0.19 in c:\users\laghoub\anaconda3\lib\site-packages (from pmdarima) (1.2.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\laghoub\anaconda3\lib\site-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\laghoub\anaconda3\lib\site-packages (from pmdarima) (0.24.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\laghoub\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\laghoub\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\laghoub\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\laghoub\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\laghoub\anaconda3\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-1.8.5

# %%
from statsmodels.tsa.arima_model import ARIMA

import pmdarima as pm

model = pm.auto_arima(indexedDataset.presence, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=15, max_q=6, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=1,
                      start_Q=1,
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=11628.625, Time=0.25 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=13264.619, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=12166.857, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=12725.220, Time=0.13 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=11629.231, Time=0.37 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=11628.943, Time=0.60 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=12459.891, Time=0.27 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=11952.239, Time=0.08 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=11568.578, Time=0.34 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=11547.252, Time=0.75 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=11625.253, Time=0.93 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=11546.213, Time=1.01 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=11620.399, Time=1.11 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=11481.035, Time=1.17 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=11603.892, Time=1.45 sec
#  ARIMA(6,0,2)(0,0,0)[0]             : AIC=11475.717, Time=2.32 sec
#  ARIMA(6,0,1)(0,0,0)[0]             : AIC=11549.488, Time=2.45 sec
#  ARIMA(7,0,2)(0,0,0)[0]             : AIC=10663.235, Time=2.11 sec
#  ARIMA(7,0,1)(0,0,0)[0]             : AIC=10667.944, Time=1.72 sec
#  ARIMA(8,0,2)(0,0,0)[0]             : AIC=10649.485, Time=2.37 sec
#  ARIMA(8,0,1)(0,0,0)[0]             : AIC=10646.421, Time=2.28 sec
#  ARIMA(8,0,0)(0,0,0)[0]             : AIC=inf, Time=0.65 sec
#  ARIMA(9,0,1)(0,0,0)[0]             : AIC=10648.345, Time=2.71 sec
#  ARIMA(7,0,0)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(9,0,0)(0,0,0)[0]             : AIC=inf, Time=0.58 sec
#  ARIMA(9,0,2)(0,0,0)[0]             : AIC=10646.697, Time=3.02 sec
#  ARIMA(8,0,1)(0,0,0)[0] intercept   : AIC=10623.832, Time=3.90 sec
#  ARIMA(7,0,1)(0,0,0)[0] intercept   : AIC=10655.341, Time=3.08 sec
#  ARIMA(8,0,0)(0,0,0)[0] intercept   : AIC=10634.248, Time=1.04 sec
#  ARIMA(9,0,1)(0,0,0)[0] intercept   : AIC=10626.943, Time=4.52 sec
#  ARIMA(8,0,2)(0,0,0)[0] intercept   : AIC=10625.711, Time=4.17 sec
#  ARIMA(7,0,0)(0,0,0)[0] intercept   : AIC=10736.513, Time=0.75 sec
#  ARIMA(7,0,2)(0,0,0)[0] intercept   : AIC=10650.286, Time=4.30 sec
#  ARIMA(9,0,0)(0,0,0)[0] intercept   : AIC=10629.345, Time=2.68 sec
#  ARIMA(9,0,2)(0,0,0)[0] intercept   : AIC=10620.647, Time=5.17 sec
#  ARIMA(10,0,2)(0,0,0)[0] intercept   : AIC=10618.940, Time=4.92 sec
#  ARIMA(10,0,1)(0,0,0)[0] intercept   : AIC=10617.827, Time=4.73 sec
#  ARIMA(10,0,0)(0,0,0)[0] intercept   : AIC=10616.020, Time=3.75 sec
#  ARIMA(11,0,0)(0,0,0)[0] intercept   : AIC=10617.830, Time=4.81 sec
#  ARIMA(11,0,1)(0,0,0)[0] intercept   : AIC=10619.726, Time=6.18 sec
#  ARIMA(10,0,0)(0,0,0)[0]             : AIC=inf, Time=1.83 sec
#
# Best model:  ARIMA(10,0,0)(0,0,0)[0] intercept
# Total fit time: 84.956 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1080
# Model:              SARIMAX(10, 0, 0)   Log Likelihood               -5296.010
# Date:                Thu, 26 May 2022   AIC                          10616.020
# Time:                        20:53:54   BIC                          10675.836
# Sample:                             0   HQIC                         10638.669
#                                - 1080
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     16.7150      3.679      4.544      0.000       9.505      23.925
# ar.L1          0.2877      0.024     11.912      0.000       0.240       0.335
# ar.L2          0.0579      0.028      2.042      0.041       0.002       0.114
# ar.L3          0.1335      0.027      5.003      0.000       0.081       0.186
# ar.L4         -0.0006      0.018     -0.031      0.975      -0.036       0.035
# ar.L5          0.0101      0.019      0.537      0.592      -0.027       0.047
# ar.L6         -0.0290      0.018     -1.588      0.112      -0.065       0.007
# ar.L7          0.7989      0.031     25.922      0.000       0.739       0.859
# ar.L8         -0.2665      0.025    -10.782      0.000      -0.315      -0.218
# ar.L9         -0.0438      0.028     -1.583      0.114      -0.098       0.010
# ar.L10        -0.1200      0.026     -4.690      0.000      -0.170      -0.070
# sigma2      1056.4926     43.541     24.264      0.000     971.153    1141.832
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1544.34
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.11   Skew:                            -0.47
# Prob(H) (two-sided):                  0.31   Kurtosis:                         8.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model = ARIMA(train, order=(10, 0, 6))  
fitted = model.fit(disp=-1)  
print(fitted.summary())

# Forecast
fc, se, conf = fitted.forecast(360, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                  720
# Model:                    ARMA(10, 6)   Log Likelihood               -3443.198
# Method:                       css-mle   S.D. of innovations             28.559
# Date:                Thu, 26 May 2022   AIC                           6922.395
# Time:                        20:57:22   BIC                           7004.822
# Sample:                    09-01-2019   HQIC                          6954.216
#                          - 08-20-2021
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              92.0236      6.700     13.734      0.000      78.891     105.156
# ar.L1.presence     -0.5949      0.056    -10.609      0.000      -0.705      -0.485
# ar.L2.presence     -0.5313      0.043    -12.268      0.000      -0.616      -0.446
# ar.L3.presence     -0.2556      0.050     -5.127      0.000      -0.353      -0.158
# ar.L4.presence     -0.1468      0.034     -4.374      0.000      -0.213      -0.081
# ar.L5.presence     -0.1517      0.033     -4.538      0.000      -0.217      -0.086
# ar.L6.presence     -0.1424      0.033     -4.254      0.000      -0.208      -0.077
# ar.L7.presence      0.8457      0.034     25.240      0.000       0.780       0.911
# ar.L8.presence      0.4501      0.060      7.465      0.000       0.332       0.568
# ar.L9.presence      0.3789      0.038      9.888      0.000       0.304       0.454
# ar.L10.presence     0.1078      0.045      2.410      0.016       0.020       0.195
# ma.L1.presence      0.8697      0.043     20.169      0.000       0.785       0.954
# ma.L2.presence      0.9492      0.002    400.731      0.000       0.945       0.954
# ma.L3.presence      0.8989      0.034     26.820      0.000       0.833       0.965
# ma.L4.presence      0.8495      0.037     22.714      0.000       0.776       0.923
# ma.L5.presence      0.9152      0.027     33.428      0.000       0.862       0.969
# ma.L6.presence      0.8172      0.041     20.113      0.000       0.738       0.897
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             1.0778           -0.0000j            1.0778           -0.0000
# AR.2             0.6235           -0.7821j            1.0002           -0.1429
# AR.3             0.6235           +0.7821j            1.0002            0.1429
# AR.4            -0.2228           -0.9750j            1.0001           -0.2858
# AR.5            -0.2228           +0.9750j            1.0001            0.2858
# AR.6            -0.9045           -0.4354j            1.0038           -0.4286
# AR.7            -0.9045           +0.4354j            1.0038            0.4286
# AR.8            -0.2793           -1.6558j            1.6792           -0.2766
# AR.9            -0.2793           +1.6558j            1.6792            0.2766
# AR.10           -3.0277           -0.0000j            3.0277           -0.5000
# MA.1             0.6343           -0.7933j            1.0157           -0.1426
# MA.2             0.6343           +0.7933j            1.0157            0.1426
# MA.3            -0.2190           -0.9828j            1.0069           -0.2849
# MA.4            -0.2190           +0.9828j            1.0069            0.2849
# MA.5            -0.9752           -0.4677j            1.0816           -0.4288
# MA.6            -0.9752           +0.4677j            1.0816            0.4288
# ------------------------------------------------------------------------------

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
arima_model = SARIMAX(train, order = (2,1,1), seasonal_order = (4,0,3,12))
arima_result = arima_model.fit()
arima_result.summary()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ==================================================================================================
# Dep. Variable:                                   presence   No. Observations:                  720
# Model:             SARIMAX(2, 1, 1)x(4, 0, [1, 2, 3], 12)   Log Likelihood               -3774.772
# Date:                                    Thu, 26 May 2022   AIC                           7571.545
# Time:                                            21:25:41   BIC                           7621.901
# Sample:                                        09-01-2019   HQIC                          7590.986
#                                              - 08-20-2021
# Covariance Type:                                      opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2624      0.076      3.445      0.001       0.113       0.412
# ar.L2         -0.2148      0.069     -3.128      0.002      -0.349      -0.080
# ma.L1         -0.8449      0.044    -19.113      0.000      -0.932      -0.758
# ar.S.L12      -0.0324      0.113     -0.287      0.774      -0.253       0.189
# ar.S.L24       0.2624      0.105      2.510      0.012       0.057       0.467
# ar.S.L36      -0.8422      0.083    -10.180      0.000      -1.004      -0.680
# ar.S.L48      -0.3532      0.070     -5.075      0.000      -0.490      -0.217
# ma.S.L12      -0.2756      0.107     -2.567      0.010      -0.486      -0.065
# ma.S.L24      -0.2103      0.111     -1.897      0.058      -0.428       0.007
# ma.S.L36       0.9203      0.119      7.704      0.000       0.686       1.154
# sigma2      2882.8067    245.153     11.759      0.000    2402.316    3363.298
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.88   Jarque-Bera (JB):               135.49
# Prob(Q):                              0.35   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.11   Skew:                            -0.97
# Prob(H) (two-sided):                  0.40   Kurtosis:                         3.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
arima_pred = arima_result.predict(start = len(train), end = len(indexedDataset)-1, typ="levels").rename("ARIMA Predictions")
arima_pred
# Out:
# 2021-08-21    104.527526
# 2021-08-22    124.997783
# 2021-08-23     76.712617
# 2021-08-24     90.530259
# 2021-08-25     78.106932
#                  ...
# 2022-08-11    117.230540
# 2022-08-12     55.329335
# 2022-08-13    108.188191
# 2022-08-14     75.989113
# 2022-08-15     75.214630
# Freq: D, Name: ARIMA Predictions, Length: 360, dtype: float64

# %%
test.plot(figsize = (16,5), legend=True)
arima_pred.plot(legend = True);

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
arima_rmse_error = rmse(test, arima_pred)
arima_mse_error = arima_rmse_error**2
mean_value = indexedDataset.presence.mean()

print(f'MSE Error: {arima_mse_error}\nRMSE Error: {arima_rmse_error}\nMean: {mean_value}')
# Out:
# MSE Error: 3063.7028949965993
# RMSE Error: 55.35072623730062
# Mean: 97.14907407407408

# %% [markdown]
# # LSTM

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
train = train.values.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-ed1cb29306f7> in <module>
# ----> 1 train = train.values.reshape(-1,1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
test = test.values.reshape(-1,1)

# %%
scaler.fit(train)
scaled_train_data = scaler.transform(train)
scaled_test_data = scaler.transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

n_input = 12
n_features= 1
generator = TimeseriesGenerator(scaled_train_data, scaled_train_data, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

lstm_model = Sequential()
lstm_model.add(LSTM(200, activation='relu', input_shape=(n_input, n_features)))
lstm_model.add(Dense(1))
lstm_model.compile(optimizer='adam', loss='mse')

lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 200)               161600
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 161,801
# Trainable params: 161,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit_generator(generator,epochs=20)
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\keras\engine\training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 708/708 [==============================] - 44s 12ms/step - loss: 0.1258
# Epoch 2/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0908
# Epoch 3/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0874
# Epoch 4/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0735
# Epoch 5/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0608
# Epoch 6/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0690
# Epoch 7/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0543
# Epoch 8/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0474
# Epoch 9/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0479
# Epoch 10/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0428
# Epoch 11/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0321
# Epoch 12/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0380
# Epoch 13/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0405
# Epoch 14/20
# 708/708 [==============================] - 9s 12ms/step - loss: 0.0243
# Epoch 15/20
# 708/708 [==============================] - 10s 14ms/step - loss: 0.0396
# Epoch 16/20
# 708/708 [==============================] - 10s 14ms/step - loss: 0.0329
# Epoch 17/20
# 708/708 [==============================] - 10s 14ms/step - loss: 0.0282
# Epoch 18/20
# 708/708 [==============================] - 9s 13ms/step - loss: 0.0292
# Epoch 19/20
# 708/708 [==============================] - 9s 13ms/step - loss: 0.0320
# Epoch 20/20
# 708/708 [==============================] - 8s 11ms/step - loss: 0.0340

# %%
losses_lstm = lstm_model.history.history['loss']
plt.figure(figsize=(12,4))
plt.xticks(np.arange(0,21,1))
plt.plot(range(len(losses_lstm)),losses_lstm);

# %%
lstm_predictions_scaled = list()

batch = scaled_train_data[-n_input:]
current_batch = batch.reshape((1, n_input, n_features))

for i in range(len(test)):   
    lstm_pred = lstm_model.predict(current_batch)[0]
    lstm_predictions_scaled.append(lstm_pred) 
    current_batch = np.append(current_batch[:,1:,:],[[lstm_pred]],axis=1)

# %%
lstm_predictions_scaled
# Out:
# [array([0.4419884], dtype=float32),
#  array([0.5610204], dtype=float32),
#  array([0.6153031], dtype=float32),
#  array([0.61292815], dtype=float32),
#  array([0.6559151], dtype=float32),
#  array([0.21880199], dtype=float32),
#  array([0.40968066], dtype=float32),
#  array([0.58745605], dtype=float32),
#  array([0.6184889], dtype=float32),
#  array([0.57747895], dtype=float32),
#  array([0.5765674], dtype=float32),
#  array([0.5455797], dtype=float32),
#  array([0.12677322], dtype=float32),
#  array([0.4269977], dtype=float32),
#  array([0.552787], dtype=float32),
#  array([0.568691], dtype=float32),
#  array([0.57085276], dtype=float32),
#  array([0.58605134], dtype=float32),
#  array([0.5716743], dtype=float32),
#  array([0.05933072], dtype=float32),
#  array([0.47571084], dtype=float32),
#  array([0.6180744], dtype=float32),
#  array([0.6448815], dtype=float32),
#  array([0.6285688], dtype=float32),
#  array([0.65466577], dtype=float32),
#  array([0.62534034], dtype=float32),
#  array([0.05038065], dtype=float32),
#  array([0.52608687], dtype=float32),
#  array([0.6670596], dtype=float32),
#  array([0.6818507], dtype=float32),
#  array([0.65108997], dtype=float32),
#  array([0.66432005], dtype=float32),
#  array([0.66883224], dtype=float32),
#  array([0.04404441], dtype=float32),
#  array([0.5444919], dtype=float32),
#  array([0.688982], dtype=float32),
#  array([0.6991295], dtype=float32),
#  array([0.6628619], dtype=float32),
#  array([0.6694253], dtype=float32),
#  array([0.7022084], dtype=float32),
#  array([0.03317655], dtype=float32),
#  array([0.5587495], dtype=float32),
#  array([0.7062051], dtype=float32),
#  array([0.71333027], dtype=float32),
#  array([0.672951], dtype=float32),
#  array([0.67697096], dtype=float32),
#  array([0.7285831], dtype=float32),
#  array([0.03085941], dtype=float32),
#  array([0.57016027], dtype=float32),
#  array([0.7177375], dtype=float32),
#  array([0.7223932], dtype=float32),
#  array([0.67882574], dtype=float32),
#  array([0.6800456], dtype=float32),
#  array([0.7405842], dtype=float32),
#  array([0.02975598], dtype=float32),
#  array([0.57539827], dtype=float32),
#  array([0.722554], dtype=float32),
#  array([0.7260084], dtype=float32),
#  array([0.68064934], dtype=float32),
#  array([0.68163306], dtype=float32),
#  array([0.74651337], dtype=float32),
#  array([0.02777237], dtype=float32),
#  array([0.57816637], dtype=float32),
#  array([0.72550905], dtype=float32),
#  array([0.7284207], dtype=float32),
#  array([0.68216443], dtype=float32),
#  array([0.68300986], dtype=float32),
#  array([0.7499931], dtype=float32),
#  array([0.02716053], dtype=float32),
#  array([0.5799391], dtype=float32),
#  array([0.7271532], dtype=float32),
#  array([0.7296197], dtype=float32),
#  array([0.68287987], dtype=float32),
#  array([0.6834527], dtype=float32),
#  array([0.75172925], dtype=float32),
#  array([0.02680013], dtype=float32),
#  array([0.58072495], dtype=float32),
#  array([0.7279306], dtype=float32),
#  array([0.73018503], dtype=float32),
#  array([0.6832144], dtype=float32),
#  array([0.6837395], dtype=float32),
#  array([0.7527912], dtype=float32),
#  array([0.02649164], dtype=float32),
#  array([0.58122444], dtype=float32),
#  array([0.7284599], dtype=float32),
#  array([0.73059916], dtype=float32),
#  array([0.6834915], dtype=float32),
#  array([0.683958], dtype=float32),
#  array([0.7534502], dtype=float32),
#  array([0.02639524], dtype=float32),
#  array([0.58153534], dtype=float32),
#  array([0.7287628], dtype=float32),
#  array([0.73082], dtype=float32),
#  array([0.6836265], dtype=float32),
#  array([0.68405145], dtype=float32),
#  array([0.75381285], dtype=float32),
#  array([0.02632064], dtype=float32),
#  array([0.5816946], dtype=float32),
#  array([0.7289287], dtype=float32),
#  array([0.730946], dtype=float32),
#  array([0.6837045], dtype=float32),
#  array([0.6841208], dtype=float32),
#  array([0.7540319], dtype=float32),
#  array([0.02626976], dtype=float32),
#  array([0.5817969], dtype=float32),
#  array([0.7290346], dtype=float32),
#  array([0.7310281], dtype=float32),
#  array([0.6837572], dtype=float32),
#  array([0.6841625], dtype=float32),
#  array([0.75416064], dtype=float32),
#  array([0.02624881], dtype=float32),
#  array([0.58185613], dtype=float32),
#  array([0.7290933], dtype=float32),
#  array([0.7310717], dtype=float32),
#  array([0.68378353], dtype=float32),
#  array([0.68418264], dtype=float32),
#  array([0.75423336], dtype=float32),
#  array([0.02623295], dtype=float32),
#  array([0.5818888], dtype=float32),
#  array([0.72912705], dtype=float32),
#  array([0.73109794], dtype=float32),
#  array([0.6837999], dtype=float32),
#  array([0.68419653], dtype=float32),
#  array([0.7542767], dtype=float32),
#  array([0.02622387], dtype=float32),
#  array([0.5819094], dtype=float32),
#  array([0.7291478], dtype=float32),
#  array([0.73111355], dtype=float32),
#  array([0.6838098], dtype=float32),
#  array([0.6842042], dtype=float32),
#  array([0.754302], dtype=float32),
#  array([0.02621946], dtype=float32),
#  array([0.58192074], dtype=float32),
#  array([0.72915924], dtype=float32),
#  array([0.7311219], dtype=float32),
#  array([0.683815], dtype=float32),
#  array([0.6842084], dtype=float32),
#  array([0.7543167], dtype=float32),
#  array([0.02621613], dtype=float32),
#  array([0.5819273], dtype=float32),
#  array([0.7291663], dtype=float32),
#  array([0.7311275], dtype=float32),
#  array([0.6838185], dtype=float32),
#  array([0.68421125], dtype=float32),
#  array([0.75432545], dtype=float32),
#  array([0.02621445], dtype=float32),
#  array([0.5819316], dtype=float32),
#  array([0.7291705], dtype=float32),
#  array([0.7311305], dtype=float32),
#  array([0.68382037], dtype=float32),
#  array([0.68421274], dtype=float32),
#  array([0.7543304], dtype=float32),
#  array([0.0262135], dtype=float32),
#  array([0.58193374], dtype=float32),
#  array([0.7291727], dtype=float32),
#  array([0.73113215], dtype=float32),
#  array([0.6838213], dtype=float32),
#  array([0.68421346], dtype=float32),
#  array([0.7543335], dtype=float32),
#  array([0.0262128], dtype=float32),
#  array([0.5819351], dtype=float32),
#  array([0.7291741], dtype=float32),
#  array([0.7311334], dtype=float32),
#  array([0.6838222], dtype=float32),
#  array([0.68421423], dtype=float32),
#  array([0.75433517], dtype=float32),
#  array([0.02621263], dtype=float32),
#  array([0.58193594], dtype=float32),
#  array([0.729175], dtype=float32),
#  array([0.7311339], dtype=float32),
#  array([0.68382245], dtype=float32),
#  array([0.68421453], dtype=float32),
#  array([0.7543361], dtype=float32),
#  array([0.02621237], dtype=float32),
#  array([0.58193624], dtype=float32),
#  array([0.7291754], dtype=float32),
#  array([0.7311342], dtype=float32),
#  array([0.6838227], dtype=float32),
#  array([0.68421465], dtype=float32),
#  array([0.75433683], dtype=float32),
#  array([0.02621221], dtype=float32),
#  array([0.5819367], dtype=float32),
#  array([0.7291757], dtype=float32),
#  array([0.73113465], dtype=float32),
#  array([0.6838229], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.75433713], dtype=float32),
#  array([0.02621206], dtype=float32),
#  array([0.5819369], dtype=float32),
#  array([0.7291759], dtype=float32),
#  array([0.7311348], dtype=float32),
#  array([0.68382293], dtype=float32),
#  array([0.68421483], dtype=float32),
#  array([0.75433743], dtype=float32),
#  array([0.02621204], dtype=float32),
#  array([0.581937], dtype=float32),
#  array([0.729176], dtype=float32),
#  array([0.7311348], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.7543375], dtype=float32),
#  array([0.02621201], dtype=float32),
#  array([0.58193696], dtype=float32),
#  array([0.729176], dtype=float32),
#  array([0.7311349], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.75433755], dtype=float32),
#  array([0.02621209], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.72917604], dtype=float32),
#  array([0.73113495], dtype=float32),
#  array([0.68382305], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.75433755], dtype=float32),
#  array([0.02621203], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.7291761], dtype=float32),
#  array([0.73113495], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.75433755], dtype=float32),
#  array([0.02621209], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.729176], dtype=float32),
#  array([0.7311349], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.75433755], dtype=float32),
#  array([0.02621197], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.72917604], dtype=float32),
#  array([0.7311349], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.75433767], dtype=float32),
#  array([0.02621206], dtype=float32),
#  array([0.5819372], dtype=float32),
#  array([0.72917604], dtype=float32),
#  array([0.7311349], dtype=float32),
#  array([0.68382305], dtype=float32),
#  array([0.68421495], dtype=float32),
#  array([0.75433767], dtype=float32),
#  array([0.026212], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.7291761], dtype=float32),
#  array([0.73113495], dtype=float32),
#  array([0.68382305], dtype=float32),
#  array([0.68421495], dtype=float32),
#  array([0.7543377], dtype=float32),
#  array([0.02621206], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.729176], dtype=float32),
#  array([0.7311349], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.75433767], dtype=float32),
#  array([0.02621203], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.729176], dtype=float32),
#  array([0.73113495], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.68421495], dtype=float32),
#  array([0.75433767], dtype=float32),
#  array([0.02621212], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.729176], dtype=float32),
#  array([0.7311349], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.7543376], dtype=float32),
#  array([0.02621204], dtype=float32),
#  array([0.58193713], dtype=float32),
#  array([0.72917604], dtype=float32),
#  array([0.7311349], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.68421495], dtype=float32),
#  array([0.7543376], dtype=float32),
#  array([0.02621212], dtype=float32),
#  array([0.58193696], dtype=float32),
#  array([0.7291759], dtype=float32),
#  array([0.7311349], dtype=float32),
#  array([0.68382293], dtype=float32),
#  array([0.68421483], dtype=float32),
#  array([0.7543376], dtype=float32),
#  array([0.02621206], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.72917604], dtype=float32),
#  array([0.7311349], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.68421495], dtype=float32),
#  array([0.75433755], dtype=float32),
#  array([0.02621203], dtype=float32),
#  array([0.58193696], dtype=float32),
#  array([0.729176], dtype=float32),
#  array([0.73113483], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.75433767], dtype=float32),
#  array([0.02621206], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.72917604], dtype=float32),
#  array([0.7311349], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.68421495], dtype=float32),
#  array([0.75433755], dtype=float32),
#  array([0.02621201], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.72917604], dtype=float32),
#  array([0.731135], dtype=float32),
#  array([0.68382305], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.75433767], dtype=float32),
#  array([0.02621206], dtype=float32),
#  array([0.5819372], dtype=float32),
#  array([0.72917604], dtype=float32),
#  array([0.73113495], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.68421495], dtype=float32),
#  array([0.75433767], dtype=float32),
#  array([0.02621204], dtype=float32),
#  array([0.58193713], dtype=float32),
#  array([0.72917616], dtype=float32),
#  array([0.731135], dtype=float32),
#  array([0.68382305], dtype=float32),
#  array([0.68421495], dtype=float32),
#  array([0.7543377], dtype=float32),
#  array([0.026212], dtype=float32),
#  array([0.5819372], dtype=float32),
#  array([0.7291761], dtype=float32),
#  array([0.731135], dtype=float32),
#  array([0.68382305], dtype=float32),
#  array([0.68421495], dtype=float32),
#  array([0.7543377], dtype=float32),
#  array([0.026212], dtype=float32),
#  array([0.5819372], dtype=float32),
#  array([0.72917604], dtype=float32),
#  array([0.731135], dtype=float32),
#  array([0.6838231], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.7543377], dtype=float32),
#  array([0.02621201], dtype=float32),
#  array([0.58193725], dtype=float32),
#  array([0.7291761], dtype=float32),
#  array([0.731135], dtype=float32),
#  array([0.68382305], dtype=float32),
#  array([0.68421495], dtype=float32),
#  array([0.7543377], dtype=float32),
#  array([0.02621209], dtype=float32),
#  array([0.5819372], dtype=float32),
#  array([0.72917616], dtype=float32),
#  array([0.7311349], dtype=float32),
#  array([0.683823], dtype=float32),
#  array([0.6842149], dtype=float32),
#  array([0.7543377], dtype=float32),
#  array([0.02621204], dtype=float32),
#  array([0.5819371], dtype=float32),
#  array([0.7291761], dtype=float32),
#  array([0.73113495], dtype=float32),
#  array([0.683823], dtype=float32)]

# %%
lstm_predictions = scaler.inverse_transform(lstm_predictions_scaled)

# %%
lstm_predictions
# Out:
# array([[ 73.81206423],
#        [ 93.69040251],
#        [102.75561756],
#        [102.3590014 ],
#        [109.53781861],
#        [ 36.53993236],
#        [ 68.41667098],
#        [ 98.10515994],
#        [103.2876476 ],
#        [ 96.43898386],
#        [ 96.28675771],
#        [ 91.1118052 ],
#        [ 21.17112829],
#        [ 71.30861446],
#        [ 92.31542999],
#        [ 94.97139955],
#        [ 95.33241034],
#        [ 97.87057459],
#        [ 95.46960598],
#        [  9.90823094],
#        [ 79.44371012],
#        [103.21842766],
#        [107.69520831],
#        [104.97099429],
#        [109.32918328],
#        [104.4318372 ],
#        [  8.41356808],
#        [ 87.85650676],
#        [111.39895326],
#        [113.86906219],
#        [108.73202437],
#        [110.94144863],
#        [111.6949845 ],
#        [  7.35541692],
#        [ 90.93014514],
#        [115.05999565],
#        [116.75463015],
#        [110.69793457],
#        [111.79402655],
#        [117.26880276],
#        [  5.54048365],
#        [ 93.31116599],
#        [117.93625665],
#        [119.1261549 ],
#        [112.38281417],
#        [113.0541501 ],
#        [121.67337728],
#        [  5.1535216 ],
#        [ 95.21676505],
#        [119.86216182],
#        [120.63966686],
#        [113.36389792],
#        [113.56761599],
#        [123.67756051],
#        [  4.96924862],
#        [ 96.09151047],
#        [120.66652268],
#        [121.24340534],
#        [113.66843981],
#        [113.83272022],
#        [124.66773224],
#        [  4.63798529],
#        [ 96.55378306],
#        [121.16001093],
#        [121.64625269],
#        [113.92145991],
#        [114.0626471 ],
#        [125.24884534],
#        [  4.53580773],
#        [ 96.8498342 ],
#        [121.4345814 ],
#        [121.84648687],
#        [114.04093748],
#        [114.13660514],
#        [125.53878474],
#        [  4.47562101],
#        [ 96.98106742],
#        [121.5644111 ],
#        [121.94090033],
#        [114.09680915],
#        [114.18449372],
#        [125.71613473],
#        [  4.42410421],
#        [ 97.06448174],
#        [121.65280241],
#        [122.01006055],
#        [114.14308518],
#        [114.220985  ],
#        [125.82618588],
#        [  4.4080049 ],
#        [ 97.11640167],
#        [121.70338851],
#        [122.04694003],
#        [114.16562098],
#        [114.23659283],
#        [125.88674587],
#        [  4.3955475 ],
#        [ 97.1429987 ],
#        [121.73109043],
#        [122.06798273],
#        [114.17865074],
#        [114.2481693 ],
#        [125.92332673],
#        [  4.38705054],
#        [ 97.16007972],
#        [121.74877864],
#        [122.08168936],
#        [114.18745005],
#        [114.25513709],
#        [125.94482732],
#        [  4.38355172],
#        [ 97.16997397],
#        [121.75858331],
#        [122.08897567],
#        [114.19184971],
#        [114.25850153],
#        [125.95697117],
#        [  4.38090272],
#        [ 97.17542875],
#        [121.76421726],
#        [122.09335542],
#        [114.19458705],
#        [114.26082081],
#        [125.96420771],
#        [  4.37938598],
#        [ 97.17887282],
#        [121.76768124],
#        [122.09596336],
#        [114.19623941],
#        [114.26210487],
#        [125.96843815],
#        [  4.37864938],
#        [ 97.18076408],
#        [121.7695924 ],
#        [122.09735692],
#        [114.19710541],
#        [114.26280165],
#        [125.97088683],
#        [  4.37809321],
#        [ 97.18185902],
#        [121.77077693],
#        [122.09829259],
#        [114.19769269],
#        [114.26327944],
#        [125.97235006],
#        [  4.37781325],
#        [ 97.1825757 ],
#        [121.77147371],
#        [122.09879029],
#        [114.19800127],
#        [114.26352829],
#        [125.97317624],
#        [  4.37765399],
#        [ 97.18293405],
#        [121.771842  ],
#        [122.099069  ],
#        [114.19816053],
#        [114.26364774],
#        [125.97369385],
#        [  4.37753703],
#        [ 97.18316299],
#        [121.77207094],
#        [122.09927803],
#        [114.19830984],
#        [114.26377714],
#        [125.97397256],
#        [  4.37750841],
#        [ 97.18330234],
#        [121.77222025],
#        [122.09935766],
#        [114.19834965],
#        [114.26382691],
#        [125.97413182],
#        [  4.3774661 ],
#        [ 97.18335211],
#        [121.77228993],
#        [122.09940743],
#        [114.19838947],
#        [114.26384681],
#        [125.97425127],
#        [  4.37743873],
#        [ 97.18343174],
#        [121.7723397 ],
#        [122.09948707],
#        [114.19841933],
#        [114.26388663],
#        [125.97430104],
#        [  4.37741385],
#        [ 97.18346161],
#        [121.77237952],
#        [122.09950697],
#        [114.19842929],
#        [114.26387668],
#        [125.97435081],
#        [  4.37741136],
#        [ 97.18348151],
#        [121.77238947],
#        [122.09950697],
#        [114.19843924],
#        [114.26388663],
#        [125.97436076],
#        [  4.37740638],
#        [ 97.18347156],
#        [121.77238947],
#        [122.09952688],
#        [114.19843924],
#        [114.26388663],
#        [125.97437072],
#        [  4.37741882],
#        [ 97.18349147],
#        [121.77239943],
#        [122.09953684],
#        [114.19844919],
#        [114.26388663],
#        [125.97437072],
#        [  4.37740887],
#        [ 97.18349147],
#        [121.77240938],
#        [122.09953684],
#        [114.19843924],
#        [114.26388663],
#        [125.97437072],
#        [  4.37741882],
#        [ 97.18349147],
#        [121.77238947],
#        [122.09952688],
#        [114.19843924],
#        [114.26388663],
#        [125.97437072],
#        [  4.37739892],
#        [ 97.18349147],
#        [121.77239943],
#        [122.09952688],
#        [114.19843924],
#        [114.26388663],
#        [125.97439063],
#        [  4.37741385],
#        [ 97.18351138],
#        [121.77239943],
#        [122.09952688],
#        [114.19844919],
#        [114.26389658],
#        [125.97439063],
#        [  4.37740389],
#        [ 97.18349147],
#        [121.77240938],
#        [122.09953684],
#        [114.19844919],
#        [114.26389658],
#        [125.97440058],
#        [  4.37741385],
#        [ 97.18349147],
#        [121.77238947],
#        [122.09952688],
#        [114.19843924],
#        [114.26388663],
#        [125.97439063],
#        [  4.37740887],
#        [ 97.18349147],
#        [121.77238947],
#        [122.09953684],
#        [114.19843924],
#        [114.26389658],
#        [125.97439063],
#        [  4.3774238 ],
#        [ 97.18349147],
#        [121.77238947],
#        [122.09952688],
#        [114.19843924],
#        [114.26388663],
#        [125.97438067],
#        [  4.37741136],
#        [ 97.18350142],
#        [121.77239943],
#        [122.09952688],
#        [114.19843924],
#        [114.26389658],
#        [125.97438067],
#        [  4.3774238 ],
#        [ 97.18347156],
#        [121.77237952],
#        [122.09952688],
#        [114.19842929],
#        [114.26387668],
#        [125.97438067],
#        [  4.37741385],
#        [ 97.18349147],
#        [121.77239943],
#        [122.09952688],
#        [114.19843924],
#        [114.26389658],
#        [125.97437072],
#        [  4.37740887],
#        [ 97.18347156],
#        [121.77238947],
#        [122.09951693],
#        [114.19843924],
#        [114.26388663],
#        [125.97439063],
#        [  4.37741385],
#        [ 97.18349147],
#        [121.77239943],
#        [122.09952688],
#        [114.19843924],
#        [114.26389658],
#        [125.97437072],
#        [  4.37740638],
#        [ 97.18349147],
#        [121.77239943],
#        [122.09954679],
#        [114.19844919],
#        [114.26388663],
#        [125.97439063],
#        [  4.37741385],
#        [ 97.18351138],
#        [121.77239943],
#        [122.09953684],
#        [114.19843924],
#        [114.26389658],
#        [125.97439063],
#        [  4.37741136],
#        [ 97.18350142],
#        [121.77241933],
#        [122.09954679],
#        [114.19844919],
#        [114.26389658],
#        [125.97440058],
#        [  4.37740389],
#        [ 97.18351138],
#        [121.77240938],
#        [122.09954679],
#        [114.19844919],
#        [114.26389658],
#        [125.97440058],
#        [  4.37740389],
#        [ 97.18351138],
#        [121.77239943],
#        [122.09954679],
#        [114.19845915],
#        [114.26388663],
#        [125.97440058],
#        [  4.37740638],
#        [ 97.18352133],
#        [121.77240938],
#        [122.09954679],
#        [114.19844919],
#        [114.26389658],
#        [125.97440058],
#        [  4.37741882],
#        [ 97.18351138],
#        [121.77241933],
#        [122.09952688],
#        [114.19843924],
#        [114.26388663],
#        [125.97440058],
#        [  4.37741136],
#        [ 97.18349147],
#        [121.77240938],
#        [122.09953684],
#        [114.19843924]])

# %%
test.plot(figsize = (16,5), legend=True)
lstm_predictions.plot(legend = True);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-68c6cbde862e> in <module>
#       1 test.plot(figsize = (16,5), legend=True)
# ----> 2 lstm_predictions.plot(legend = True);
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
list = lstm_predictions[0]

# %%
list
# Out:
# array([73.81206423])

# %%
# Out:
#                                                               presence
# date
# 2021-08-21 00:00:00                                                 98
# 2021-08-22 00:00:00                                                117
# 2021-08-23 00:00:00                                                127
# 2021-08-24 00:00:00                                                118
# 2021-08-25 00:00:00                                                116
# ...                                                                ...
# 2022-08-13 00:00:00                                                104
# 2022-08-14 00:00:00                                                136
# 2022-08-15 00:00:00                                                134
# ARIMA_Predictions    2021-08-21    104.527526
# 2021-08-22    124.997...
# LSTM_Predictions     [[73.81206423044205], [93.69040250778198], [10...
#
# [362 rows x 1 columns]
